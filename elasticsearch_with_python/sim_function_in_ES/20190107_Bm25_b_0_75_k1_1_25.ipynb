# %%
import json
from elasticsearch import Elasticsearch, helpers
import pandas as pd
import numpy as np

# %%
es = Elasticsearch([{'host': 'localhost', 'port': 9200}], timeout = 300)

# %%
data = json.load(open(".../data_formular/formular.txt"))

# %%
data[:5]
# Out:
# ['\\sqrt { 2 x + 7 }',
#  '\\sqrt { \\frac { 1 } { - 1 + x } }',
#  '\\sqrt { - 3 x + 4 }',
#  '\\sqrt { 1 + x ^ { 2 } }',
#  '\\sqrt { 0,09.64 }']

# %%
data_filter = []
for i in data:
    if len(i.split())>2:
        print(i)
        data_filter.append(i)
# Out:
# \sqrt { 2 x + 7 }
# \sqrt { \frac { 1 } { - 1 + x } }
# \sqrt { - 3 x + 4 }
# \sqrt { 1 + x ^ { 2 } }
# \sqrt { 0,09.64 }
# \sqrt { 12,1.360 }
# \sqrt { 2 ^ { 2 } .3 ^ { 4 } }
# \sqrt { 0,36 a ^ { 2 } }
# a < 0
# \hat { a } \% _ { 0 }
# a > 1
# \frac { 1 } { a - b }
# a > b
# \sqrt { \frac { 289 } { 225 } }
# \sqrt { \frac { 14 } { 25 } }
# \sqrt { \frac { 0,25 } { 9 } }
# \sqrt { \frac { 8,1 } { 1,6 } }
# \sqrt { 4 x ^ { 2 } + 4 x + 1 } = 6
# \sqrt { 9,11 }
# \sqrt { 39,82 }
# \sqrt { 9,119 } \approx 3,019
# \sqrt { 911,9 }
# \sqrt { 91190 }
# \sqrt { 0,09119 }
# \sqrt { 0,0009119 }
# \frac { 5 } { 3 \sqrt { 8 } } ; \frac { 2 } { \sqrt { b } }
# \frac { 5 } { 5 - 2 \sqrt { 3 } } ; \frac { 2 a } { 1 - \sqrt { a } }
# a \geq 0
# a \neq 1
# \frac { 4 } { \sqrt { 7 } + \sqrt { 5 } } ; \frac { 6 a } { 2 \sqrt { a } - \sqrt { b } }
# \frac { 5 } { \sqrt { 10 } } \frac { 5 } { 2 \sqrt { 5 } } , \frac { 1 } { 3 \sqrt { 20 } } , \quad \frac { 2 \sqrt { 2 } + 2 } { 5 \sqrt { 2 } } , \frac { y + b \cdot \sqrt { y } } { b \cdot \sqrt { y } }
# B = \sqrt { 16 x + 16 } - \sqrt { 9 x + 9 } + \sqrt { 4 x + 4 } + \sqrt { x + 1 }
# x \geq - 1
# | ( 11 )
# a > 0
# a \neq 1
# \sqrt { - 9 a } - \sqrt { 9 + 12 a + 4 a ^ { 2 } }
# a = - 9
# 1 + \frac { 3 m } { m - 2 } \sqrt { m ^ { 2 } - 4 m + 4 }
# m = 1,5
# \sqrt { 1 - 10 a + 25 a ^ { 2 } } - 4 a
# a = \sqrt { 2 }
# 4 x - \sqrt { 9 x ^ { 2 } + 6 x + 1 }
# x = - \sqrt { 3 }
# \frac { 5 } { 3 } \sqrt { 15 x } - \sqrt { 15 x } - 2 = \frac { 1 } { 3 } \sqrt { 15 x }
# y = \frac { 1 } { 2 } x + 5
# x = 1 + \sqrt { 5 }
# y = \sqrt { 5 }
# y = x
# y = 2 x + 2
# y = x
# A B C
# y = x + 1
# y = - x + 3
# y = x + 1
# y = - x + 3
# A , B , C
# A B C
# y = 1,5 x + 2
# y = x + 2
# y = 0,5 x - 3
# y = x - 3
# y = 1,5 x - 1
# y = 0,5 x + 3
# A B C
# A C = 0,9 m
# B C = 1,2 m
# x = \frac { 2 } { 3 }
# = \frac { 3 } { 4 }
# \alpha = \frac { 3 } { 2 }
# A B C
# ( \wedge \operatorname { cos } B = 0 , 8 )
# A B C
# B C = 11 c n
# A B C = 38 ^ { \circ } , A C B = 30 ^ { \circ }
# \frac { 5 } { 3 }
# \frac { 5 } { 4 }
# \frac { 3 } { 5 }
# \frac { 3 } { 5 }
# \frac { P R } { R S }
# \frac { P R } { Q R }
# \frac { P S } { S R }
# \frac { S R } { Q R }
# \frac { 2 a } { \sqrt { 3 } }
# \frac { a } { \sqrt { 3 } }
# \frac { \sqrt { 3 } } { 2 }
# 2 \sqrt { 3 } a ^ { 2 }
# 60 ^ { \circ }
# 70 ^ { 0 }
# B , C , D
# B , C , D
# 1 , B , C , D , E
# 22 c m
# 6 c m
# A B C
# A B = 3 , A C = 4 , B C = 5
# A , B , C
# x A y
# A x , B y
# A x , B y
# \widehat {CO{\rm{D}}} = {90^0}
# C D = A C + B D
# A C . B D
# A B C
# 1 c m
# A B C
# 6 c m ^ { 2 }
# \sqrt { 3 } c m ^ { 2 }
# \frac { 3 \sqrt { 3 } } { 4 }
# 3 \sqrt { 3 } c m ^ { 2 }
# 1 c m
# 1 c m
# 2 x + y = 4
# 3 x + 2 y = 5
# \left\{ \begin{array}{l}{ 4 x - 4 y = 2 }\\{ - 2 x + 2 y = - 1 }\end{array} \right.
# \left\{\begin{matrix} \dfrac{1}{3}x - y = \dfrac{2}{3} & & \\ x -3y = 2 & & \end{matrix}\right.
# y = \frac { 1 } { 2 } x ^ { 2 } ; y = x ^ { 2 } ; y = 2 x ^ { 2 }
# A , B , C
# x = - 1,5
# A ^ { \prime } , B ^ { \prime } , C ^ { \prime }
# x = 1,5
# C ^ { \prime }
# a , b ^ { \prime } , c
# 4 x ^ { 2 } + 4 x + 1 = 0
# 13852 x ^ { 2 } - 14 x + 1 = 0
# 5 x ^ { 2 } - 6 x + 1 = 0
# - 3 x ^ { 2 } + 4 \sqrt { 6 } x + 4 = 0
# x^2 – x – 2 = 0
# u + v = 12
# u v = 28
# u > v
# u + v = 3 ; u v = 6
# A O B
# A O C , A O ^ { \prime } D
# B C , B D
# E B D
# E B D
# S _ { A }
# M , N
# M B N
# A B = 40
# M K = 3
# A M B
# B C = R
# B , C
# A B C , B A C
# A S C - M C
# A B C
# B C = 6 c m
# \hat { A } = 40 ^ { \circ }
# A H = 4 c m
# A B C D
# \left. \begin{array} { r } { A B } \\ { S \ddot { A } \cdot \square } \end{array} \right.
# 60 ^ { \circ }
# \left. \begin{array} { r } { B C } \\ { s \ddot { A } \cdot \square } \end{array} \right.
# 90 ^ { 0 }
# \left. \begin{array} { c } { C D } \\ { s \ddot { A } \cdot \square } \end{array} \right.
# 120 ^ { 0 }
# A B C D
# A B C D
# A B C D
# 60 ^ { \circ }
# 2 d m
# A B C D
# A B = 10 c m
# B C = 4 c m
# 7 c m
# 352 cm ^ { 2 }
# 3,2 c m
# 1,8 c m
# 2,1 c m
# 12,8 c m ^ { 2 }
# 8,5 m m
# 2 c m
# 5 c m
# 8 m m
# A B C D
# 120 ^ { \circ }
# \frac { \sqrt { 2 } } { 4 }
# \frac { \sqrt { 2 } } { 2 }
# \sqrt { 2 }
# \sqrt { 2 }
# A A ^ { \prime }
# \sqrt { 2 + \sqrt { x } } = 3
# \sqrt { 7 }
# y = 2 x + n
# A B C
# \sin {\rm{A}} = {2 \over 3}
# \operatorname { tan } B
# \frac { 3 } { 5 }
# \frac { \sqrt { 5 } } { 3 }
# \frac { 2 } { \sqrt { 5 } }
# \frac { \sqrt { 5 } } { 2 }
# A B C
# ( O ^ { \prime }
# C D = B D = O ^ { \prime } D
# A O = C O = O D
# C D = C O = B D
# C D = O D = B D
# O O ^ { \prime }
# 3 c m
# 2 c m
# \sqrt { 8,1 } \cdot \sqrt { 100 } \cdot \sqrt { 0,9 }
# \sqrt { \frac { 25 } { 64 } }
# \sqrt { \frac { 16 } { 25 } : \frac { 49 } { 64 } }
# \frac { \sqrt { 63 } } { \sqrt { 7 } }
# \sqrt { 8 ^ { 2 } + 6 ^ { 2 } }
# \sqrt { x ^ { 2 } } = 5
# \sqrt { x ^ { 2 } } = | - 2
# \sqrt { 16 x ^ { 2 } } = 3
# \sqrt { 9 x ^ { 2 } } = | - 2
# \sqrt { 16.9 }
# \sqrt { 160.2,5 }
# \sqrt { 0,9.10 ^ { 2 } .3,6 }
# \sqrt { 2 x - 1 } = 5
# \sqrt { 2 x - 1 } = | - 3
# \sqrt { 50 }
# \sqrt { 27 }
# 5 \sqrt { 3 }
# \sqrt { 48 }
# 3 \sqrt { 5 }
# \frac { 5 } { 3 \sqrt { 7 } }
# \frac { 4 } { \sqrt { 5 } - 3 }
# \frac { a } { \sqrt { a } + 1 }
# \sqrt { 18 } - 2 \sqrt { 32 } + 3 \sqrt { 50 } - 4 \sqrt { 8 }
# 3 \sqrt { 27 } + \sqrt { 75 } - 3 \sqrt { 48 } - 4 \sqrt { 12 }
# 2 \sqrt { 5 } - 2 \sqrt { 108 } + 3 \sqrt { 20 } + 5 \sqrt { 27 }
# \frac { 7 } { \sqrt { 3 } } \frac { 3 } { 2 \sqrt { 5 } } ; \frac { 5 } { 3 \sqrt { 12 } } , \frac { 2 } { 3 \sqrt { 20 } }
# \frac { \sqrt { 3 } + 3 } { 5 \sqrt { 3 } } : \frac { 7 - \sqrt { 7 } } { \sqrt { 7 } - 1 }
# \frac { 5 } { \sqrt { 5 } + 2 } , \frac { 3 } { \sqrt { 3 } - 1 } , \frac { 2 } { \sqrt { 5 } + \sqrt { 3 } }
# \frac { \sqrt { 5 } + 2 } { \sqrt { 5 } - 2 } , \frac { \sqrt { 7 } - \sqrt { 5 } } { \sqrt { 7 } + \sqrt { 5 } }
# \frac { y + a \sqrt { y } } { a \sqrt { y } } , \frac { b - \sqrt { b } } { \sqrt { b } - 1 }
# \frac { b } { 5 + \sqrt { b } } _ { : } \frac { p } { 2 \sqrt { p } - 1 } , \frac { \sqrt { a } + \sqrt { b } } { \sqrt { a } - \sqrt { b } }
# \frac { 3 + 2 \sqrt { 3 } } { \sqrt { 3 } } - \frac { 2 \sqrt { 3 } + \sqrt { 15 } } { \sqrt { 5 } + 2 }
# \frac { 5 \sqrt { 2 } - 2 \sqrt { 5 } } { \sqrt { 10 } } - \frac { 3 } { \sqrt { 5 } - \sqrt { 2 } }
# \frac { \sqrt { 15 } - \sqrt { 12 } } { \sqrt { 5 } - 2 } = \frac { 1 } { 2 - \sqrt { 3 } }
# \frac { 4 } { 1 + \sqrt { 3 } } \frac { \sqrt { 3 } - 1 } { \sqrt { 3 } + 1 }
# \sqrt { 4 - 2 \sqrt { 3 } } + \sqrt { \frac { 2 } { 2 - \sqrt { 3 } } } - \sqrt { 27 }
# \frac { \sqrt { 2 } } { \sqrt { \sqrt { 2 } + 1 } - 1 } \frac { \sqrt { 2 } } { \sqrt { \sqrt { 2 } + 1 } + 1 }
# - \frac { 1 } { 2 } \sqrt { 108 } - \frac { 1 } { 15 } \sqrt { 75 } - 22 \sqrt { 363 } + \sqrt { 12 }
# 2 \sqrt { \frac { 27 } { 2 } } - \sqrt { \frac { 48 } { 9 } } - \frac { 2 } { 5 } \sqrt { \frac { 75 } { 18 } }
# 2 y \sqrt { 45 } + 3 \sqrt { 20 y ^ { 2 } }
# 3 x \sqrt { 72 x } - 9 \sqrt { 50 x ^ { 3 } }
# x \geq 0
# \sqrt { 9 - 4 \sqrt { 5 } } - \sqrt { 14 + 6 \sqrt { 5 } }
# \sqrt { 13 - \sqrt { 160 } } - \sqrt { 53 + 4 \sqrt { 60 } }
# \sqrt [ 3 ] { 3 x + 4 } = 4
# 3 + \sqrt [ 3 ] { 5 x + 3 } = 0
# \frac { \sqrt { x } + 7 x + 13 } { x + 3 \sqrt { x } - 10 } + \frac { \sqrt { x } + 5 } { 2 - \sqrt { x } } - \frac { \sqrt { x } - 4 } { \sqrt { x } + 5 }
# y = x
# x \neq 0
# x = 2
# y = 6
# c m ^ { 3 }
# y = 3 x
# = - 60000 c + 10000000
# y = 5 x - 3
# y = \frac { 2 } { x } + 4
# y = 3 x ^ { 2 } + 1
# y = a x + 4
# y = - 3 x - 1
# y = a x - 2
# y = 3 x + b
# y = 2 x - 3
# 0 x + 3 y = 3
# . . x + \ldots y = 45
# \ldots x + \ldots y = 375
# \left\{ \begin{array} { l } { \dots x + \ldots y = 45 } \\ { \dots x + \ldots y = 375 } \end{array} \right.
# x = 2 + \ldots
# m x ^ { 2 } + n x + 1
# \left\{ \begin{array} { l } { 2 x + y = 2 } \\ { x - y = 4 } \end{array} \right.
# \left\{ \begin{array} { l } { 2 x + y = 2 } \\ { x - y = 4 } \end{array} \right.
# \left\{ \begin{array} { l } { 3 x = 6 } \\ { x - y = 4 } \end{array} \right. \Leftrightarrow \left\{ \begin{array} { l } { x = 2 } \\ { y = - 2 } \end{array} \right.
# S = x ^ { 2 }
# S = x ^ { 2 }
# y = \frac { 1 } { 4 } x ^ { 2 }
# y = - \frac { 1 } { 4 } x ^ { 2 }
# y = \frac { 1 } { 4 } x ^ { 2 }
# y = - \frac { 1 } { 4 } x ^ { 2 }
# y = x ^ { 2 }
# y = - x ^ { 2 }
# - 2 , \sqrt { 3 } , - \sqrt { 3 }
# - 3 , - 32
# y = \frac { x ^ { 2 } } { 2 }
# \Delta > 0
# x + \frac { b } { 2 a } = \pm \ldots
# \Delta = 0
# \Delta < 0
# 235 x ^ { 2 } + 87 x - 197 = 0
# x ^ { 2 } - 2 x - 3 m ^ { 2 } - 1 = 0
# 2 x ^ { 2 } - 3 x - 5 = 0
# \left. \begin{array} { r } { b } \\ { - a } \\ { a } \end{array} \right.
# \frac { c } { a }
# \frac { x - 1 } { x + 1 } + \frac { 1 } { x - 1 } = \frac { 4 } { x ^ { 2 } - 1 }
# B D = 3,5 c m
# M B ^ { 2 } + M C ^ { 2 }
# m O n = x
# A B C = x ; A C B = y
# y = 90 ^ { \circ } - x
# \operatorname { in } x = \frac { 1 } { 2 }
# \operatorname { sin } x = 0,174
# \operatorname { sin } x = 0,519
# \operatorname { cos } x = 0,342
# \operatorname { tan } x = 1,254
# \operatorname { cot } x = 0,856
# 60 ^ { \circ }
# 40 ^ { \circ } 12 ^ { \prime }
# 52 ^ { \circ } 54
# o _ { 36 }
# 25 ^ { \circ } 18 ^ { \prime }
# \sqrt { 15 }
# \sqrt { 11 }
# \sqrt { x } = 15
# 2 \sqrt { x } = 14
# \sqrt { x } < \sqrt { 2 }
# \sqrt { 2 x } < 4
# \sqrt { 4 - 2 \sqrt { 3 } } - \sqrt { 3 } = - 1
# \sqrt { 16 } \cdot \sqrt { 25 } + \sqrt { 196 } : \sqrt { 49 }
# 36 : \sqrt { 2.3 ^ { 2 } \cdot 18 } - \sqrt { 169 }
# \sqrt { \sqrt { 81 } }
# \sqrt { 3 ^ { 2 } + 4 ^ { 2 } }
# 2 \sqrt { a ^ { 2 } } - 5 a
# a < 0
# \sqrt { 25 a ^ { 2 } } + 3 a
# \sqrt { 9 a ^ { 4 } } + 3 a ^ { 2 }
# 5 \sqrt { 4 a ^ { 6 } }
# 3 a ^ { 3 }
# a < 0
# x ^ { 2 } - 3
# x ^ { 2 } - 6
# x ^ { 2 }
# 2 \sqrt { 3 } x + 3
# x ^ { 2 }
# 2 \sqrt { 5 } x + 5
# \sqrt { 7 } \cdot \sqrt { 63 }
# \sqrt { 2,5 } \cdot \sqrt { 30 } \cdot \sqrt { 48 }
# \sqrt { 0,4 } \cdot \sqrt { 6,4 }
# \sqrt { 2,7 } \cdot \sqrt { 5 } \cdot \sqrt { 1,5 }
# x = - \sqrt { 2 }
# a = - 2 ; b = - \sqrt { 3 }
# \sqrt { \frac { 16 } { 25 } }
# \frac { \sqrt { 16 } } { \sqrt { 25 } }
# \frac { \sqrt { 999 } } { \sqrt { 111 } }
# \frac { \sqrt { 52 } } { \sqrt { 117 } }
# 3 \sqrt { 5 } ; 2 \sqrt { 6 } ; \sqrt { 29 } ; 4 \sqrt { 2 }
# 6 \sqrt { 2 } ; \sqrt { 38 } ; 3 \sqrt { 7 } ; \quad 2 \sqrt { 14 }
# \sqrt { 25 x } - \sqrt { 16 x } = 9
# \frac { x ^ { 2 } - 3 } { x + \sqrt { 3 } }
# \frac { 1 - a \sqrt { a } } { a - \sqrt { a } }
# a \geq 0 ; a \neq 1
# \frac { 1 } { 2 } \sqrt { 48 } - 2 \sqrt { 75 } - \sqrt { 11 } + 5 \sqrt { 1 }
# \sqrt { 150 } + \sqrt { 1,6 } \cdot \sqrt { 60 } + 4,5 . \sqrt { \frac { 2 } { 3 } } - \sqrt { 6 }
# \sqrt [ 3 ] { 123 }
# 5 \sqrt [ 3 ] { 6 }
# 6 \sqrt [ 3 ] { 5 }
# x y - y \sqrt { x } + \sqrt { x } - 1
# \sqrt { a x } - \sqrt { b y } + \sqrt { b x } - \sqrt { a y }
# \sqrt { a + b } + \sqrt { a ^ { 2 } - b ^ { 2 } }
# 12 - \sqrt { x } - x
# \frac { a \sqrt { b } + b \sqrt { a } } { \sqrt { a b } } : \frac { 1 } { \sqrt { a } - \sqrt { b } } = a - b
# y = - \frac { 1 } { 2 } x + 3
# x _ { 1 } , x _ { 2 }
# x _ { 1 } < x _ { 2 }
# a , b
# y = 1 - 5 x
# y = - 0,5 x
# y = 2 x ^ { 2 } + 3
# 20 c m
# y = a x + 3
# x = 1
# y = 2,5
# x = 4
# y = 3 x + b
# y = a x + 5
# y = a x + 3
# y = - 2 x
# x = 2
# y = 7
# y = \frac { 1 } { 2 } x + 2
# y = - x + 2
# y = \frac { 1 } { 2 } x + 2
# y = - x + 2
# A , B
# A B C
# A B C
# x ^ { 2 }
# 60 ^ { \circ }
# 60 ^ { \circ }
# \frac { \operatorname { sin } 25 ^ { \circ } } { \operatorname { cos } 65 ^ { \circ } }
# \operatorname { tan } 58 ^ { \circ } - \operatorname { cot } 32 ^ { \circ }
# = \frac { b } { c }
# \alpha = \frac { b } { c }
# \operatorname { tg } \alpha = \frac { a } { c }
# \alpha = \frac { a } { c }
# \operatorname { sin } ^ { 2 } \hat { I } \pm + \operatorname { cos } ^ { 2 } \hat { I } \pm = 1
# \operatorname { tg } \alpha = \frac { \operatorname { sin } \alpha } { \operatorname { cos } \alpha }
# A B C D
# A B = 12 c m , B C = 5 c m
# B , C , D
# 5 c m
# 6 c m
# 4 c m
# 3 c m
# 7 c m
# 15 c m , A B = 24 c m
# A B , A C
# B , C
# A D E
# 2 A B
# x A y
# x A y
# A B C
# 2 A D = A B + A C - B C
# O O ^ { \prime }
# A B = 24 c m
# A B ; O
# x + 2 y = 4
# x - y = 1
# \left\{ \begin{array} { l } { 2 x + b y = - 4 } \\ { b x - a y = - 5 } \end{array} \right.
# \left\{\begin{matrix} \dfrac{1}{x} - \dfrac{1}{y} = 1& & \\ \dfrac{3}{x} + \dfrac{4}{y} = 5& & \end{matrix}\right.
# u = \frac { 1 } { x } , v = \frac { 1 } { y }
# \left\{\begin{matrix} \dfrac{1}{x - 2} + \dfrac{1}{y -1} = 2 & & \\ \dfrac{2}{x - 2} - \dfrac{3}{y - 1} = 1 & & \end{matrix}\right.
# u = \frac { 1 } { x - 2 } , \quad v = \frac { 1 } { y - 1 }
# c m ^ { 3 }
# y = \frac { 3 } { 2 } x ^ { 2 } , y = - \frac { 3 } { 2 } x ^ { 2 }
# \sqrt { 3 } ; \sqrt { 7 }
# y = a x ^ { 2 }
# 2 x ^ { 2 } + 5 x + 2 = 0
# 2 x ^ { 2 } - 17 x + 1 = 0
# \Delta = \ldots , x _ { 1 } + x _ { 2 } = \ldots , x _ { 1 } x _ { 2 } = \dots
# 5 x ^ { 2 } - x - 35 = 0
# \Delta = \ldots , x _ { 1 } + x _ { 2 } = \ldots , x _ { 1 } x _ { 2 } = \dots
# 8 x ^ { 2 } - x + 1 = 0
# \Delta = \ldots , x _ { 1 } + x _ { 2 } = \ldots , x _ { 1 } x _ { 2 } = \dots
# 25 x ^ { 2 } + 10 x + 1 = 0
# \Delta = \ldots , x _ { 1 } + x _ { 2 } = \ldots , x _ { 1 } x _ { 2 } = \dots
# x ^ { 2 } - 7 x + 12 = 0
# x ^ { 2 } + 7 x + 12 = 0
# x ^ { 2 } - 2 x + m = 0
# a x ^ { 2 } + b x + c = 0
# x _ { 1 }
# x _ { 2 }
# a x ^ { 2 } + b x + c
# 2 x ^ { 2 } - 5 x + 3
# 3 x ^ { 2 } + 8 x + 2
# 40 ^ { \circ }
# A _ { m B }
# \left. \begin{array} { c } { \square } \\ { A n B } \end{array} \right.
# A , B , C , D , M , N , P , Q
# A M , C P , B N , D Q
# R = 2
# 60 ^ { \circ }
# A B C
# A D = A C
# D B C
# 0 H > O K
# 55 ^ { \circ }
# A B = 3 c m
# 55 ^ { \circ }
# A _ { m B }
# M _ { 1 }
# M _ { 2 }
# M _ { 1 } , M _ { 2 }
# A _ { m B }
# A M _ { 1 } B
# A M _ { 2 } B < 55 ^ { 0 }
# A B C D
# A B C + A D C = 180 ^ { \circ }
# A C , B D , A B
# A B C D
# D A B = 8 0 ^ { 0 }
# D A M = 30 ^ { 0 }
# B M C = 70 ^ { 0 }
# M A B
# B C M
# \left. \begin{array} { c } { \wedge } \\ { A M B } \end{array} \right.
# D M C
# \left. \begin{array} { c } { \wedge } \\ { A M D } \end{array} \right.
# M C D
# B C D
# 2 c m
# A B C
# a = 3 c m
# A B C
# A B C
# I J K
# A O B
# 4 c m
# 6 c m
# 36 ^ { \circ }
# A m B
# A O B = 60 ^ { \circ }
# 5,1 c m
# 4 c m
# R = 2 c m
# A O B = 75 ^ { 0 }
# A p B
# A q B
# A p B
# O A q B
# 4 c m
# 13 c m
# 3 c m
# 5 m m
# 8 m m
# 1 800 000
# A B C D
# A B > A D
# 2 a ^ { 2 }
# \frac { 2 \sqrt { 2 } } { 3 }
# \frac { 2 \sqrt { 3 } } { 3 }
# \frac { 4 } { 3 }
# \frac { 4 } { 5 }
# y = a x ^ { 2 }
# x _ { 1 } , x _ { 2 }
# 3 x ^ { 2 } - a x - b = 0
# x _ { 1 } + x _ { 2 }
# - \frac { a } { 3 }
# \frac { a } { 3 }
# \frac { b } { 3 }
# \left. \begin{array} { r } { b } \\ { - 3 } \\ { - 3 } \end{array} \right.
# A B C
# A C = 15 c m
# H B = 16 cm
# A B C
# P A B
# P C D
# \left. \begin{array} { r } { B Q } \\ { s \ddot { A } \cdot \square } \end{array} \right.
# \left. \begin{array} { r } { Q D } \\ { s \ddot { A } ^ { \cdot } \square } \end{array} \right.
# B P D + A Q C
# \sqrt { 2 }
# \sqrt { 8 }
# \sqrt { x } < 4 ; \sqrt { x } \geq 5
# \sqrt { \frac { 16 } { 9 } : \frac { 4 } { 81 } }
# \sqrt { \frac { 16 } { 9 } : \frac { 4 } { 81 } } = \sqrt { \frac { 16 } { 9 } , \frac { 81 } { 4 } } = \sqrt { \frac { 16 } { 4 } \cdot \frac { 81 } { 9 } }
# = \sqrt { 4.9 } = \sqrt { 36 } = 6
# \sqrt { \frac { 16 } { 9 } : \frac { 4 } { 81 } } = \sqrt { \frac { 16 } { 9 } } : \sqrt { \frac { 4 } { 81 } }
# = \frac { 4 } { 3 } : \frac { 2 } { 9 } = \frac { 4 } { 3 } , \frac { 4.9 } { 3.2 } = 6
# \sqrt { x } = 2
# \sqrt { x } + 1 = 5
# \sqrt { x - 1 } + 1 = 4
# \sqrt { x - 1 } = \sqrt { 3 }
# \sqrt { \frac { 2 a } { 3 } }
# \sqrt { 2 - a }
# \sqrt { 2 a + 5 }
# \sqrt { 3 } \cdot \sqrt { 27 }
# \sqrt { 4,9 } \cdot \sqrt { 60 } \cdot \sqrt { 6 }
# \sqrt { 0,9 } \cdot \sqrt { 6,4 }
# \sqrt { 6,3 } \cdot \sqrt { 6,4 } \cdot \sqrt { 7 }
# \sqrt { 4 a ^ { 2 } }
# a \geq 0
# x \geq 2
# x \neq 5
# x \geq 5
# x < 4
# \sqrt { 0,09.64 }
# \sqrt { 12,1.360 }
# \sqrt { 7 } \cdot \sqrt { 63 }
# \sqrt { 2,5 } \cdot \sqrt { 30 } \cdot \sqrt { 48 }
# \sqrt { 0,4 } \cdot \sqrt { 6,4 }
# \sqrt { \frac { 20 ^ { 2 } - 16 ^ { 2 } } { 16 } }
# \sqrt { \frac { 2 ^ { \frac { 1 } { 4 } } \cdot 1 ^ { \frac { 7 } { 9 } } } { 3 ^ { \frac { 6 } { 25 } } } }
# \frac { \sqrt { 75 } } { \sqrt { 3 } }
# \frac { \sqrt { \frac { 11 } { 25 } } } { \sqrt { \frac { 14 } { 25 } } }
# \sqrt { 50 x ^ { 2 } y ^ { 4 } }
# x \geq 0
# \sqrt { 63 a ^ { 4 } b ^ { 2 } }
# b < 0
# 2 x \sqrt { 5 }
# x \geq 0
# - 3 a b \sqrt { 5 }
# a b \geq 0
# \sqrt { \frac { 2 } { 3 } }
# \frac { 1 } { \sqrt { 5 } }
# \frac { \sqrt { 5 } } { 5 }
# \frac { 3 } { 2 \sqrt { 5 } } = \frac { 3 \ldots . } { 2 \sqrt { 5 } \dots } = \frac { 3 \sqrt { 5 } } { 10 }
# 4 \sqrt { 12 } - 3 \sqrt { 48 } + 5 \sqrt { 75 } - 2 \sqrt { 108 }
# \sqrt { 20 } - 3 \sqrt { 80 } + 5 \sqrt { 45 } - 2 \sqrt { 125 }
# \sqrt { 60 } - 4 \sqrt { \frac { 3 } { 5 } } + \sqrt { \frac { 5 } { 3 } }
# 4 \sqrt { 2 x } - 7 \sqrt { 18 x } - 5 \sqrt { 8 x } + \sqrt { 32 x }
# \sqrt { 50 x ^ { 2 } y ^ { 5 } } - 13 y \sqrt { 2 x ^ { 2 } y ^ { 3 } } + x y \sqrt { 98 y ^ { 3 } }
# \frac { 1 } { P } \leq \frac { 5 } { 2 }
# - \sqrt [ 3 ] { 125 } = - 5
# \sqrt [ 3 ] { - 125 } = - 5
# - \sqrt [ 3 ] { x } = \sqrt [ 3 ] { - x }
# \sqrt [ 3 ] { 27 }
# \sqrt [ 3 ] { 64 }
# \sqrt [ 3 ] { 8.27 }
# \sqrt [ 3 ] { 8 } \cdot \sqrt [ 3 ] { 27 }
# \sqrt [ 3 ] { \frac { 64 } { 125 } }
# \frac { \sqrt [ 3 ] { 64 } } { \sqrt [ 3 ] { 125 } }
# \sqrt [ 3 ] { x } = 6
# \sqrt [ 3 ] { 2 x } = 4
# \sqrt [ 3 ] { 2 x - 5 } = 3
# \sqrt { 50 } - 3 \sqrt { 98 } + 2 \sqrt { 8 } + \sqrt { 32 } - 5 \sqrt { 18 }
# \frac { 1 } { 2 } \sqrt { 48 } - 2 \sqrt { 75 } - \sqrt { 108 } + 5 \sqrt { \frac { 1 } { 3 } }
# \frac { 2 \sqrt { 3 } - 3 \sqrt { 2 } } { \sqrt { 3 } - \sqrt { 2 } } , \frac { 5 } { 1 + \sqrt { 6 } }
# \frac { 3 } { \sqrt { 7 } + 2 } + \sqrt { \frac { 2 } { 8 + 3 \sqrt { 7 } } }
# \frac { 1 } { \sqrt { 2 } - \sqrt { 3 } } \sqrt { \frac { 3 \sqrt { 2 } - 2 \sqrt { 3 } } { 3 \sqrt { 2 } + 2 \sqrt { 3 } } }
# \frac { 2 \sqrt { 3 + \sqrt { 5 - \sqrt { 13 + \sqrt { 48 } } } } } { \sqrt { 6 } + \sqrt { 2 } }
# P < \frac { 1 } { 2 }
# F = \frac { 9 } { 5 } C + 32
# y = 3 x - 1
# y = - x + 2
# y = - x - 3
# \alpha _ { 1 } , \alpha _ { 2 } , \alpha _ { 3 }
# \alpha _ { 1 } , \alpha _ { 2 } , \alpha _ { 3 }
# y = \sqrt { 2 } x
# y = a x + 2
# y = - x , y = - x + 2
# y = 2 x , y = 2 x + 3
# y = - \sqrt { 3 } x + 1
# 3 y - 6 x = - 2
#  …x + …y = 540
# 2 x + 0 y = 2
# x - 2 y = 1
# \left\{ \begin{array} { l } { - 2 x + y = 3 } \\ { x + 2 y = 1 } \end{array} \right.
# \left\{ \begin{array}{l}4x - y = 8\\x - \dfrac{1}{4}y = 2\end{array} \right.
# \left\{ \begin{array} { l } { 4 x + 2 y = 1 } \\ { 2 x + y = 2 } \end{array} \right.
# \left\{ \begin{array} { l } { x - y = 1 } \\ { 2 x + y = 1 } \end{array} \right.
# \left\{ \begin{array} { l } { 4 x - y = 2 } \\ { x + 3 y = 7 } \end{array} \right.
# \left\{ \begin{array} { l } { 4 x - y = 8 } \\ { 2 x - y = 10 } \end{array} \right.
# \left\{ \begin{array} { l } { 3 x - 2 y = 1 } \\ { 6 x - 2 y = 4 } \end{array} \right.
# \left\{ \begin{array} { l } { 2 x + 5 y = 1 } \\ { 6 x - 15 y = 4 } \end{array} \right.
# \left\{ \begin{array}{l}\dfrac{x}{2} - \dfrac{y}{3} = 1\\3x - 2y = 6\end{array} \right.
# \left\{ \begin{array}{l}\dfrac{{2x}}{3} - \dfrac{{5y}}{3} = 1\\4x - 10y = 6\end{array} \right.
# \left\{ \begin{array} { l } { x + y \sqrt { 3 } = 0 } \\ { x \sqrt { 3 } + 2 y = 2 } \end{array} \right.
# y = a x + b
# x + y = \dots
# . . x + \dots y =
# \left\{ \begin{array} { l } { x + y = \ldots } \\ { \dots x + \ldots y = } \end{array} \right.
# y = x ^ { 2 }
# y = - x ^ { 2 }
# y = x ^ { 2 }
# y = - x ^ { 2 }
# y = 2 x ^ { 2 }
# y = - 2 x ^ { 2 }
# y = - \frac { 1 } { 2 } x ^ { 2 }
# y = \frac { 1 } { 4 } x ^ { 2 }
# y = a x ^ { 2 }
# y = \frac { 1 } { 4 } x ^ { 2 }
# y = \overline { 2 } x + m
# \Rightarrow \ldots x ^ { 2 } - \ldots x + \ldots = 0
# x ^ { 2 } - 8 x + 15 = 0
# x ^ { 2 } - 2 x + m = 0
# 3 x ^ { 2 } + 5 x - 6 = 0
# B = \frac { x _ { 1 } } { x _ { 2 } - 1 } + \frac { x _ { 2 } } { x _ { 1 } - 1 }
# C = | x _ { 1 } - x _ { 2 } |
# \frac { x _ { 1 } + 2 } { x _ { 1 } } + \frac { x _ { 2 } + 2 } { x _ { 2 } }
# x ^ { 2 } - 2 m x + m - 2 = 0
# M = \frac { - 24 } { x _ { 1 } ^ { 2 } + x _ { 2 } ^ { 2 } - 6 x _ { 1 } x _ { 2 } }
# A B = \frac { 2 } { 3 } A C
# O D = \frac { a } { 2 }
# \frac { A B } { A C } = \frac { 3 } { 4 }
# \alpha = \frac { 3 } { 10 }
# A B C = x
# \operatorname { sin } ^ { 2 } x + \operatorname { cos } ^ { 2 } x
# \dfrac{{{\mathop{\rm cosx}\nolimits} }}{{{\mathop{\rm s}\nolimits} {\rm{inx}}}}
# 15 ^ { o } ; 52 ^ { o } ; 64 ^ { o }
# 15 ^ { \circ } 20 ^ { \prime } ; 52 ^ { \circ } 18 ^ { \prime } ; 64 ^ { \circ } 24 ^ { \prime }
# \frac { \operatorname { sin } 25 ^ { \circ } } { \operatorname { cos } 65 ^ { \circ } }
# \sqrt { \frac { a } { 3 } }
# \sqrt { - 5 a }
# \sqrt { 4 - a }
# \sqrt { 3 a + 7 }
# m ^ { 2 } + V ^ { 2 } = V ^ { 2 } + m ^ { 2 }
# - 2 m V
# m ^ { 2 } - 2 m V + V ^ { 2 } = V ^ { 2 } - 2 m V + m ^ { 2 }
# m - V = V - m
# 2 m = 2 V
# m = V
# \sqrt { 16 } \times \sqrt { 25 }
# \sqrt { \frac { 2 a } { 3 } }
# \sqrt { \frac { 3 a } { 8 } }
# \sqrt { 13 a } \cdot \sqrt { \frac { 52 } { a } }
# a > 0
# \sqrt { 5 a } \cdot \sqrt { 45 a } - 3 a
# \sqrt { 13 ^ { 2 } - 12 ^ { 2 } }
# \sqrt { 17 ^ { 2 } - 8 ^ { 2 } }
# \sqrt { 117 ^ { 2 } - 108 ^ { 2 } }
# \sqrt { 313 ^ { 2 } - 312 ^ { 2 } }
# 2 \sqrt { 3 }
# - \sqrt { 5 }
# \sqrt { \frac { 9 } { 16 } , 5 ^ { \frac { 4 } { 9 } } \cdot 0,01 }
# \sqrt { 1,44.1,21 - 1,44.0,4 }
# \sqrt { \frac { 165 ^ { 2 } - 124 ^ { 2 } } { 164 } }
# \sqrt { \frac { 149 ^ { 2 } - 76 ^ { 2 } } { 457 ^ { 2 } - 384 ^ { 2 } } }
# a b ^ { 2 } \cdot \sqrt { \frac { 3 } { a ^ { 2 } b ^ { 4 } } }
# a < 0 , \quad b \hat { a } \% _ { 0 } 0
# a > 3
# \sqrt { \frac { 9 + 12 a + 4 a ^ { 2 } } { b ^ { 2 } } }
# a \hat { a } \% _ { 0 } \neq - 1,5
# b < 0
# a < b < 0
# 1 c m
# M , N , P , Q
# M N P Q
# x ^ { 2 } = 3,5
# x ^ { 2 } = 132
# 3 \sqrt { 5 }
# 1,2 \sqrt { 5 }
# a b ^ { 4 } \sqrt { a }
# a \geq 0
# \sqrt { 54 }
# \sqrt { 108 }
# 0,1 \sqrt { 20000 }
# - 0,05 \sqrt { 28800 }
# \sqrt { 7 \cdot 63 \cdot a ^ { 2 } }
# x ≥ 0; y ≥ 0
# \hat { a } \% _ { 0 } J
# \frac { 2 } { 2 a - 1 } \sqrt { 5 a ^ { 2 } ( 1 - 4 a + 4 a ^ { 2 } }
# a > 0,5
# \sqrt {{4 \over 5}}
# \sqrt { \frac { 3 } { 125 } }
# \sqrt { \frac { 3 } { 2 a ^ { 2 } } }
# _ { 5 } \sqrt { \frac { 1 } { 5 } } + \frac { 1 } { 2 } \sqrt { 20 } + \sqrt { 5 }
# \sqrt { \frac { 1 } { 2 } } + \sqrt { 4,5 } + \sqrt { 12,5 }
# \sqrt { 20 } - \sqrt { 45 } + 3 \sqrt { 18 } + \sqrt { 72 }
# 1 . \sqrt { 200 } + 2 . \sqrt { 0,08 } + 0,4 \cdot \sqrt { 50 }
# a > 0 , b > 0
# 5 \sqrt { a } - 4 b \sqrt { 25 a ^ { 3 } } + 5 a \sqrt { 16 a b ^ { 2 } } - 2 \sqrt { 9 a }
# 5 a \sqrt { 64 a b ^ { 3 } } - \sqrt { 3 } \cdot \sqrt { 12 a ^ { 3 } b ^ { 3 } } + 2 a b \sqrt { 9 a b } - 5 b \sqrt { 81 a ^ { 3 } b }
# \frac { 3 } { 2 } \sqrt { 6 } + 2 \sqrt { \frac { 2 } { 3 } } - 4 \sqrt { \frac { 3 } { 2 } } = \frac { \sqrt { 6 } } { 6 }
# x > 0
# 2 \hat { a } \% _ { 0 } 1
# \frac { a + b } { b ^ { 2 } } \sqrt { \frac { a ^ { 2 } b ^ { 4 } } { a ^ { 2 } + 2 a b + b ^ { 2 } } } = | a
# a + b > 0
# \frac { 1 } { 2 + \sqrt { 3 } } + \frac { 1 } { 2 - \sqrt { 3 } }
# \frac { 1 } { 2 }
# \sqrt [ 3 ] { 1728 } : \sqrt [ 3 ] { 64 }
# y = 2 x
# y = - 2 x
# y = 0,5 x
# y = 0,5 x + 2
# y = 2 x + b
# y = 2 x + 3 k
# y = \frac { 2 } { 3 } x + 2
# y = - \frac { 3 } { 2 } x + 2
# O _ { y }
# y = \frac { 2 } { 3 } x + 2
# y = - \frac { 3 } { 2 } x + 2
# y = a x - 4
# y = 2 x - 1
# y = - 3 x + 2
# y = a x + 3
# y = x + 1 ; y = \frac { 1 } { \sqrt { 3 } } x + \sqrt { 3 } ; y = \sqrt { 3 } x - \sqrt { 3 }
# \alpha , \beta , \gamma
# \operatorname { tg } \alpha = 1 , \quad \operatorname { tg } \beta = \frac { 1 } { \sqrt { 3 } } ; \quad \operatorname { tg } \gamma = \sqrt { 3 }
# \hat { A } = \alpha
# \alpha = 45 ^ { \circ } \Leftrightarrow \frac { A C } { A B } = 1
# \alpha = 60 ^ { \circ } \Leftrightarrow \frac { A C } { A B } = \sqrt { 3 }
# \hat { C } = \beta
# \operatorname { sin } 70 ^ { \circ } 13 ^ { \prime }
# \operatorname { cos } 25 ^ { \circ } 32 ^ { \prime }
# \operatorname { an } 43 ^ { \circ } 10 ^ { \prime }
# \operatorname { cot } 32 ^ { \circ } 15 ^ { \circ }
# O x y
# O A = R
# O C A B
# A B , A C
# B , C
# A B C
# O B = 2 c m , O A = 4 c m
# AE.AB = AF.AC
# 5 x + 4 y = 8
# 3 x + 5 y = - 3
# \left\{ \begin{array} { l } { y = 3 - 2 x } \\ { y = 3 x - 1 } \end{array} \right.
# \left\{\begin{matrix} y = -\frac{1}{2}x+ 3 & & \\ y = -\frac{1}{2}x + 1 & & \end{matrix}\right.
# \left\{ \begin{array} { c } { 2 y = - 3 x } \\ { 3 y = 2 x } \end{array} \right.
# \left\{\begin{matrix} 3x - y = 3 & & \\ x - \frac{1}{3}y = 1 & & \end{matrix}\right.
# \left\{ \begin{array} { c } { 2 x - y = 1 } \\ { x - 2 y = - 1 } \end{array} \right.
# \left\{ \begin{array} { l } { 2 x + y = 4 } \\ { - x + y = 1 } \end{array} \right.
# \left\{ \begin{array} { c } { x + y = 2 } \\ { 3 x + 3 y = 2 } \end{array} \right.
# \left\{ \begin{array} { c } { 3 x - 2 y = 1 } \\ { - 6 x + 4 y = 0 } \end{array} \right.
# x - a
# x + 1
# x - 3
# y = a x + b
# \left. \begin{array} { r } { 4 } \\ { 45 } \end{array} \right.
# \frac { 6 } { 5 }
# s = 4 t ^ { 2 }
# F = a v ^ { 2 }
# 2 m / s
# v = 10 m
# v = 20 m / s
# 12 000 N
# y = - 0.75 x ^ { 2 }
# x ^ { 2 } + 8 x = - 2
# x ^ { 2 } + 2 x = \frac { 1 } { 3 }
# 2 x ^ { 2 } - 7 x + 3 = 0
# 6 x ^ { 2 } + x + 5 = 0
# 6 x ^ { 2 } + x - 5 = 0
# 3 x ^ { 2 } + 5 x + 2 = 0
# y ^ { 2 } - 8 y + 16 = 0
# 16 z ^ { 2 } + 24 z + 9 = 0
# 7 x ^ { 2 } - 6 \sqrt { 2 } x + 4 = 0
# a x ^ { 2 } | + 2 b \hat { a } \in T M _ { X } + c = 0
# 3 x ^ { 2 } - 2 x = x ^ { 2 } + 3
# x _ { 1 } = \frac { - b + \sqrt { \Delta } } { 2 a } ; \quad x _ { 2 } = \frac { - b - \sqrt { 4 } } { 2 a }
# u + v = 42
# u v = 441
# u + v = - 42
# u v = - 400
# u \hat { a } \in ^ { 66 } v = 5
# u v = 24
# Q \in R
# M A N
# 30 ^ { \circ }
# P C Q
# P C Q
# 136 ^ { \circ }
# M A N
# M A ^ { 2 } = M B . M C
# B A x ; A C B
# \left. \begin{array} { c } { \wedge } \\ { A P O } \end{array} \right.
# P B T ^ { \wedge }
# B T P + 2 . T P B = 9 0 ^ { 0 }
# 6 400 km
# E S = E M
# S _ { A }
# S B C
# B A C
# S A = S D
# A B C D
# A B C D
# A , B , C
# A P = A D
# A , B , C
# 40 000 km
# H = 1 0 cm
# \backslash ( H O = 2 c m )
# A B C
# 1 c m
# B C = a
# \frac { 1 } { 2 }
# \frac { 1 } { 3 }
# A B C
# 90 ^ { 0 }
# A B C
# C D = C E
# C D = C H
# \hat { r } ^ { \prime } , A B C
# B C = 6 c n
# B A C = 8 _ { 0 } ^ { 0 }
# 2 c m
# c m ^ { 2 }
# C A O
# 30 ^ { 0 }
# A B C D
# G E F
# 4 k m
# 5 k m
# A B C D
# 20 c m
# A B C
# B C = a
# A B C
# A B , A C
# D O E = 60 ^ { \circ }
# B D . C E
# \hat { r } ^ { \prime } B O D
# \hat { r } ^ { \prime } O E D
# B D E
# A B C
# B D ^ { 2 } = A D . C D
# B C D E
# 100 ; 121 ; 144 ; 169 ; 0
# \sqrt { 100 } = 10
# 100 ; 121 ; 196 ; 225 ; 0
# 16 : 36 ; 25
# \sqrt { 81 } ; \sqrt { 9 } ; \sqrt { 64 }
# 8 1 ; 9 ; 6 4
# \sqrt { 8 }
# \sqrt { 50 }
# 2 + \sqrt { 3 }
# 3 + \sqrt { 2 }
# \sqrt { 9 - 4 \sqrt { 5 } } - \sqrt { 5 } = - 2
# \sqrt { 11 - 2 \sqrt { 10 } } - \sqrt { 10 } = - 1
# \sqrt { 4 + 2 \sqrt { 3 } } - \sqrt { 4 - 2 \sqrt { 3 } } = 2
# x \geq 1
# a < 1
# \sqrt { 0,16 x ^ { 2 } }
# x < 0
# x < 2
# \sqrt { \frac { x } { 15 } } \sqrt { \frac { 5 x } { 3 } }
# x > 0
# \sqrt { 3 x } \cdot \sqrt { \frac { 12 } { x } }
# x > 0
# \sqrt { 3 } x = \sqrt { 27 }
# \sqrt { 3 } x - \sqrt { 27 } = \sqrt { 12 } - \sqrt { 75 }
# \sqrt { 5 } x ^ { 2 } - \sqrt { 20 } = 0
# \frac { 2 x ^ { 2 } } { \sqrt { 3 } } - \sqrt { 12 } = 0
# \frac { \sqrt { 10 } - \sqrt { 2 } } { \sqrt { 5 } - 1 } , \frac { 2 - \sqrt { 2 } } { 1 - \sqrt { 2 } }
# \frac { 2 } { \sqrt { 7 } + \sqrt { 3 } } + \sqrt { \frac { 2 } { 5 - \sqrt { 21 } } }
# p = \frac { a + b + c } { 2 }
# A B = a , A C = \frac { a } { 2 } , B C = \frac { a \sqrt { 7 } } { 2 }
# \sqrt [ 3 ] { 216 }
# \sqrt [ 3 ] { - 512 }
# \sqrt [ 3 ] { 729 }
# \sqrt [ 3 ] { - 0,064 }
# \sqrt [ 3 ] { 0,027 }
# M = \frac { x } { 4 } + \sqrt [ 3 ] { \frac { x } { 3 } }
# x = 192
# N = 2 y + \sqrt [ 3 ] { - 45 y }
# y = 75
# \sqrt [ 3 ] { 64 } \dots \sqrt { 64 }
# \sqrt [ 3 ] { 0,001 \dots } .0,01
# \frac { 1 } { - 4 } , \sqrt [ 3 ] { \frac { 8 } { - 125 } }
# \sqrt { 7 - 2 \sqrt { 10 } } - \sqrt { 6 - 2 \sqrt { 5 } }
# \sqrt { 42 - 10 \sqrt { 17 } } + \sqrt { 33 - 8 \sqrt { 17 } }
# \sqrt { 3 - \sqrt { 5 } } - \sqrt { 3 + \sqrt { 5 } }
# y = 1
# y = 2 x + 1
# y = - 2 x + 2
# y = 2 x + b
# y = a x + 1
# y = 2 m x + 1
# y = x + 3
# y = m x - 1
# y = \sqrt { 3 } x - 1
# 45 ^ { \circ }
# 30 ^ { \circ }
# y = 3 x
# y = - 2 x + 105
# \left\{ \begin{array} { l } { 3 x + y = 1 } \\ { 6 x + 2 y = 0 } \end{array} \right.
# \left\{ \begin{array} { l } { x - y = 1 } \\ { 2 x - 2 y = 4 } \end{array} \right.
# \left\{ \begin{array} { l } { x + y = 2 } \\ { x - y = 0 } \end{array} \right.
# \left\{ \begin{array} { l } { x + 2 y = 3 } \\ { x + y = 2 } \end{array} \right.
# \left\{ \begin{array} { l } { 2 x + y = 5 } \\ { 3 x + 2 y = 8 } \end{array} \right.
# \left\{ \begin{array} { l } { 6 x - 3 y = 3 } \\ { - 6 x + 5 y = 3 } \end{array} \right.
# y = - x ^ { 2 }
# y = x ^ { 2 }
# x \neq 0
# x = 0
# y = x ^ { 2 }
# y = - x ^ { 2 }
# y = - \frac { 1 } { 2 } x ^ { 2 }
# y = - \frac { 1 } { 2 } x ^ { 2 }
# y = - \frac { 1 } { 2 } x ^ { 2 }
# K = \frac { m v ^ { 2 } } { 2 }
# y = a x ^ { 2 }
# y = a x + b
# y = \frac { 1 } { 2 }
# y = \frac { 1 } { 4 } x ^ { 2 }
# \Leftrightarrow x ^ { 2 } + 2 x - 24 = 0
# 2 x ^ { 2 } + 3 x = 15 x
# 2 x ^ { 2 } + 3 x = 15 x \Leftrightarrow 2 x + 3 = 15
# \Leftrightarrow 2 x = 12 \Leftrightarrow x = 6
# {x^2} + 2x - 8 = 0
# 7 x ^ { 2 } - 3 x + 2 = 0
# 3 x ^ { 2 } - 2 \sqrt { 3 } x + 1 = 0
# - 2 x ^ { 2 } + 5 x + 2 = 0
# x ^ { 2 } - 250 x - m ^ { 2 } = 0
# 5 x ^ { 2 } - 2 x - 1 = 0
# - x ^ { 2 } + 5 x + 2 = 0
# 2016 x ^ { 2 } - 2017 x + 1 = 0
# 2016 x ^ { 2 } + 2017 + 1 = 0
# A . B = 0
# B = 0
# x ^ { 2 } + 2 x + m = 0
# x ^ { 2 } - 2 m x - 1 = 0
# x _ { 1 } ^ { 2 } + x _ { 2 } ^ { 2 } - x _ { 1 } x _ { 2 } = 15
# x _ { 1 } ^ { 2 } + x _ { 2 } ^ { 2 } - x _ { 1 } x _ { 2 } > 7
# x _ { 1 } ^ { 2 } + x _ { 2 } ^ { 2 } - x _ { 1 } x _ { 2 } - 20 \leq 0
# E = {x_1}^2 + {x_2}^2 - {x_1}{x_2} + 13
# \left. \begin{array} { l } { \wedge } \\ { C A B = x } \end{array} \right.
# 30 ^ { 0 }
# 60 ^ { \circ }
# 45 ^ { \circ }
# x = 40,542 ^ { \circ }
# \operatorname { sin } 76 ^ { \circ } ; \operatorname { cos } 31 ^ { \circ } ; \operatorname { tan } 83 ^ { \circ } ; \operatorname { cot } 88 ^ { \circ }
# \operatorname { cos } y = 0,79 ; \operatorname { cot } y = 2,44
# B C = 5 c m ; A B = 3 c m
# B C = 1 3 c m ; A C = 12 c m
# BC = 5\sqrt 2 cm;AB = 5cm
# A B = a \sqrt { 3 } ; A C = a
# px = \frac { 1 } { 3 }
# : \operatorname { sin } 60 ^ { \circ } , \operatorname { cos } 75 ^ { \circ } , \operatorname { sin } 52 ^ { \circ } 30 ^ { \prime }
# \operatorname { log } _ { x } = \frac { 2 } { 3 }
# \operatorname { cos } x = 0.6
# c = \frac { 3 } { 4 }
# x = \frac { 3 } { 2 }
# \operatorname { sin } x = 0,2368
# \operatorname { cos } x = 0,6224
# \operatorname { tan } x = 2,154
# \operatorname { cot } x = 3,251
# \operatorname { in } = 00
# \operatorname { cos } 22 ^ { \circ }
# 78 ^ { \circ }
# \operatorname { tan } 52 ^ { \circ }
# t 14 ^ { o }
# 32 ^ { \circ }
# 32 ^ { \circ }
# \operatorname { tan } 25 ^ { \circ }
# \operatorname { sin } 25 ^ { \circ }
# \operatorname { tan } 45 ^ { \circ }
# 45 ^ { \circ }
# + 32 ^ { \circ }
# 32 ^ { \circ }
# \sqrt { 3 }
# \sqrt { 41 }
# \sqrt { 47 }
# 2 \sqrt { a ^ { 2 } }
# \sqrt { 3 } \times \sqrt { 75 }
# \frac { y } { x } \sqrt { \frac { x ^ { 2 } } { y ^ { 4 } } }
# x > 0 , y \hat { a } \% _ { 0 }
# y ^ { 2 }
# \sqrt { \frac { x ^ { 4 } } { 4 y ^ { 2 } } }
# y < 0
# 5 x y . \sqrt { \frac { 25 x ^ { 2 } } { y ^ { 6 } } }
# x < 0 , y > 0
# 2 x ^ { 3 } y ^ { 3 } \cdot \sqrt { \frac { 16 } { x ^ { 4 } y ^ { 8 } } }
# x \hat { a } \% _ { 0 } 0 , y \hat { a } \% _ { 0 } 0
# , 01 = \sqrt { 0,0001 }
# - 0,5 = \sqrt { - 0,25 }
# \sqrt { 39 } < 7
# \sqrt { 39 } > 6
# \sqrt { 911 }
# \sqrt { 988 }
# a \geq 0 ; b \geq 0
# 3 \sqrt { 5 } ; - 5 \sqrt { 2 } ; - \frac { 2 } { 3 } \sqrt { x y }
# x y \geq 0 ; x \sqrt { \frac { 2 } { x } }
# x > 0
# 3 \sqrt { 3 }
# \sqrt { 12 }
# 3 \sqrt { 5 }
# \frac { 1 } { 3 } \sqrt { 51 }
# \frac { 1 } { 5 } \sqrt { 150 }
# \frac { 1 } { 2 } \sqrt { 6 }
# 6 \sqrt { \frac { 1 } { 2 } }
# x \geq 0
# 2 \sqrt { 3 x } - 4 \sqrt { 3 x } + 27 - 3 \sqrt { 3 x }
# 3 \sqrt { 2 x } - 5 \sqrt { 8 x } + 7 \sqrt { 18 x } + 28
# \frac { 3 } { \sqrt { 3 } + 1 } , \frac { 2 } { \sqrt { 3 } - 1 } , \frac { 2 + \sqrt { 3 } } { 2 - \sqrt { 3 } } , \frac { b } { 3 + \sqrt { b } } , \frac { p } { 2 \sqrt { p } - 1 }
# \frac { 2 } { \sqrt { 6 } - \sqrt { 5 } } ; \frac { 3 } { \sqrt { 10 } + \sqrt { 7 } } ; \frac { 1 } { \sqrt { x } - \sqrt { y } } , \frac { 2 a b } { \sqrt { a } - \sqrt { b } }
# a b \sqrt { 1 + \frac { 1 } { a ^ { 2 } b ^ { 2 } } }
# \sqrt { \frac { a } { b ^ { 3 } } + b ^ { 4 } }
# \sqrt [ 3 ] { 512 } ; \sqrt [ 3 ] { - 729 } ; \sqrt [ 3 ] { 0,064 } , \sqrt [ 3 ] { - 0,216 } ; \sqrt [ 3 ] { - 0,008 }
# \sqrt [ 3 ] { 27 } - \sqrt [ 3 ] { - 8 } - \sqrt [ 3 ] { 125 }
# \frac { \sqrt [ 3 ] { 135 } } { \sqrt [ 3 ] { 5 } } - \sqrt [ 3 ] { 54 } \cdot \sqrt [ 3 ] { 4 }
# y = x
# y = 2 x
# O x y
# O _ { y }
# y = 4
# y = 2 x , y = x
# A , B
# O A B
# y = \sqrt { 3 } x + \sqrt { 3 }
# y = \sqrt { 5 } x + \sqrt { 5 }
# \sqrt { 5 }
# \alpha _ { 1 } , \alpha _ { 2 } , a _ { 3 }
# y = - 2 x + 3
# y = - 2 x + 3
# y = a x + b
# a = 2
# a = 3
# y = \sqrt { 3 } x
# 45 ^ { \circ }
# s 75 ^ { \circ }
# \operatorname { sin } 52 ^ { \circ } 30 ^ { \prime }
# 82 ^ { \circ }
# \frac { \operatorname { sin } \alpha } { \operatorname { cos } \alpha }
# \frac { \operatorname { cos } \alpha } { \operatorname { sin } \alpha }
# n a ^ { 2 } + \operatorname { cos } \alpha ^ { 2 } = 1
# \operatorname { sin } x = 0,2368
# \operatorname { cos } x = 0,6224
# \operatorname { tan } x = 2,154
# \operatorname { cot } x = 3,251
# - 25 ^ { \circ }
# 63 ^ { \circ } 15 ^ { \prime }
# \operatorname { tan } 73 ^ { \circ } 20 ^ { \prime }
# \operatorname { tan } 45 ^ { \circ }
# t 2 ^ { \circ }
# \operatorname { cot } 37 ^ { \circ } 40 ^ { \prime }
# \operatorname { sin } 78 ^ { \circ } , \operatorname { cos } 14 ^ { \circ } , \operatorname { sin } 47 ^ { \circ } , \operatorname { cos } 87 ^ { \circ }
# \operatorname { tan } 73 ^ { \circ } , \operatorname { cot } 25 ^ { \circ } , \operatorname { tan } 62 ^ { \circ } , \operatorname { cot } 38
# A C = 8 c m , A D = 9,6 c m , A B C = 90 ^ { \circ }
# A C B = 54 ^ { \circ }
# A C D = 74 ^ { \circ }
# \left. \begin{array} { c } { \wedge } \\ { A D C } \end{array} \right.
# 2 k m / h
# 70 ^ { \circ }
# A C = 2 c m , B C = 5 c m
# B A C = x , A B C = y
# x – y
# sin 23°36’ ≈ 0,4;
# cos66°24’ ≈ 0,4;
# tg21°48’ ≈ 0,4.
# O x y
# A B C
# E , D , C
# D E < B C
# C H = D K
# E H = E K
# E A = E C
# A B > C D
# 1 c m
# 3 x - y = 2
# x + 5 y = 3
# 4 x - 3 y = - 1
# x + 5 y = 0
# 4 x + 0 y = - 2
# 0 x + 2 y = 5
# \frac { 2 } { 15 }
# S = \pi R ^ { 2 }
# \pi \hat { a } \% _ { 0 } \quad 3 , 14
# S = \pi R ^ { 2 }
# c m ^ { 2 }
# y = \frac { - 1 } { 2 } x ^ { 2 }
# y = a x ^ { 2 }
# x = - 3
# y = 8
# x + \frac { b } { 2 a } = \pm
# a > 0
# a x ^ { 2 } + b x + c = 0
# a x ^ { 2 } + b x + c > 0
# 15 x ^ { 2 } + 4 x - 2005 = 0
# - \frac { 19 } { 5 } x ^ { 2 } - \sqrt { 7 } x + 1890 = 0
# v = 3 t ^ { 2 } - 30 t + 135
# t = 5
# 4 x ^ { 2 } + 2 x - 5 = 0
# 9 x ^ { 2 } - 12 x + 4 = 0
# 5 x ^ { 2 } + x + 2 = 0
# 159 x ^ { 2 } - 2 x - 1 = 0
# 12 x ^ { 2 } - 8 x + 1 = 0 ; x _ { 1 } = \frac { 1 } { 2 }
# 2 x ^ { 2 } - 7 x - 39 = 0 ; x _ { 1 } = - 3
# x ^ { 2 } + x - 2 + \sqrt { 2 } = 0 ; x _ { 1 } = - \sqrt { 2 }
# x ^ { 2 } - 2 m x + m - 1 = 0 ; x _ { 1 } = 2
# A , B , C
# A O B = 100 ^ { \circ }
# A C = 45 ^ { 0 }
# C , B , D
# M A . M B = M C \cdot M D
# A B , B C , C A
# S M =
# S N = S A
# B A x
# A , B , C
# A M = A C \cdot A N
# A B , C D
# A O C = A I C
# A B C
# D B = D C
# D C B = \frac { 1 } { 2 } A C B
# A B D C
# A , B , D , C
# \frac { 2 \pi R } { 360 } =
# R _ { 1 }
# R _ { 2 }
# R _ { 1 } > R _ { 2 }
# R _ { 1 } = 10,5 cm
# R _ { 2 } = 7,8 c m
# A B C
# O A H
# A B C
# A B C D
# A B D = A C D
# S C B
# A B C D
# V _ { 1 }
# V _ { 2 }
# V _ { 1 } = V _ { 2 }
# V _ { 1 } = 2 V _ { 2 }
# V _ { 2 } = 2 V _ { 1 }
# V _ { 2 } = 3 V _ { 1 }
# V _ { 1 } = 3 V _ { 2 }
# O A = O B
# A O S
# S _ { A }
# A B = 2 R
# M O N
# A P B
# A M . B N = R ^ { 2 }
# \frac { S _ { M O N } } { S _ { A P B } }
# \frac { R } { 2 }
# A P B
# A , O , B
# O A = a , O B = b
# a , b
# A O C
# B D O
# A C . B D
# A B D C
# C O A = 60 ^ { \circ }
# C O A = 60 ^ { \circ }
# A O C
# B O D
# 2 c m
# A B C
# \hat { B } = 45 ^ { 0 }
# \hat { C } = 30 ^ { \circ }
# A C = 8
# 4 \sqrt { 2 }
# 4 \sqrt { 3 }
# 4 \sqrt { 6 }
# A ^ { \prime } B ^ { \prime }
# P A = A B = 4 c m
# A B C
# B C = 4 d m
# A C B = 30 ^ { 0 }
# m ^ { 2 }
# m ^ { 3 }
# \sqrt { 2 x } ; \sqrt { 4 x + 3 } ; \sqrt { 2 - 3 x } ; \sqrt { 2 x ^ { 2 } + 1 }
# \,\sqrt {\dfrac{{ - 3}}{{2x + 4}}} ;\dfrac{{x - 5}}{{\sqrt { - 4x} }}.
# \sqrt { a ^ { 2 } }
# | a |
# a ^ { 2 }
# \sqrt { a ^ { 2 } }
# | a |
# \sqrt { 16.25 }
# \sqrt { 16 } \cdot \sqrt { 25 }
# \sqrt { 36.49 }
# \sqrt { 36 } . \sqrt { 49 }
# \sqrt { \frac { 100 } { 4 } }
# \frac { \sqrt { 100 } } { \sqrt { 4 } }
# \sqrt { \frac { 400 } { 25 } }
# \frac { \sqrt { 400 } } { \sqrt { 25 } }
# \sqrt { \frac { 4 x } { 9 } } \sqrt { \frac { 3 x } { 4 } }
# x \geq 0
# \sqrt { 2 x } \cdot \sqrt { 18 x }
# x \geq 0
# \sqrt { \frac { 49 } { 16 } }
# \sqrt { \frac { 1 } { 16 } }
# \sqrt { \frac { 14 } { 25 } }
# \sqrt { \frac { 2,5 } { 3,6 } }
# \sqrt { 5 + 2 \sqrt { 6 } } - \sqrt { 5 - 2 \sqrt { 6 } }
# \sqrt { 8 + \sqrt { 60 } } - \sqrt { 8 - 2 \sqrt { 15 } }
# \sqrt { 4 - \sqrt { 7 } } + \sqrt { 4 + \sqrt { 7 } }
# \sqrt { 5 \sqrt { 3 } + 5 \sqrt { 48 - 10 \sqrt { 7 + 4 \sqrt { 3 } } } }
# x \geq 4
# x \neq 2
# \sqrt { x - 4 \sqrt { x - 4 } }
# x \geq 4
# A = \sqrt { x + 2 } \cdot \sqrt { x - 3 }
# 2 \sqrt { 28 } + 3 \sqrt { 63 } - 2 \sqrt { 112 } - \sqrt { 175 }
# \sqrt { 2 } \cdot \sqrt { 7 + 3 \sqrt { 5 } } - \frac { 4 } { \sqrt { 5 } - 1 }
# \frac { 1 } { 2 \sqrt { 3 } + 3 } - \frac { 1 } { 2 \sqrt { 3 } - 3 }
# \sqrt { 32 } ; 2 \sqrt { 75 } ; 3 \sqrt { 80 } ; \frac { 5 } { 6 } \sqrt { 48 } ; \sqrt { 108 }
# 12 \sqrt { 7 }
# \frac { 1 } { 2 - \sqrt { 5 } } + \frac { 1 } { 2 + \sqrt { 5 } }
# \frac { 3 } { 2 } \sqrt { 6 } + 2 \sqrt { \frac { 2 } { 3 } } - 4 \sqrt { \frac { 3 } { 2 } }
# \frac { 2 + \sqrt { 3 } } { 2 - \sqrt { 3 } } \frac { 2 - \sqrt { 3 } } { 2 + \sqrt { 3 } }
# \frac { 2 } { \sqrt { 3 } - 1 } + \frac { 3 } { \sqrt { 3 } - 2 } + \frac { 12 } { 3 - \sqrt { 3 } }
# \frac { 2 \sqrt { 5 } - 5 \sqrt { 2 } } { \sqrt { 2 } - \sqrt { 5 } } + \frac { 6 } { 2 - \sqrt { 10 } } + \sqrt { 67 + 12 \sqrt { 7 } }
# \frac { x \sqrt { y } + y \sqrt { x } } { \sqrt { x } + \sqrt { y } } - \sqrt { x y }
# x > 0 , y > 0
# a \geq 0 , a \neq 1
# x > 0 , x \neq 1
# \frac { 15 \sqrt { x } - 11 } { x + 2 \sqrt { x } - 3 } + \frac { 3 \sqrt { x } - 2 } { 1 - \sqrt { x } } - \frac { 3 } { \sqrt { x } + 3 }
# x \geq 0 , x \neq 1
# \frac { a \sqrt { b } + b \sqrt { a } } { \sqrt { a b } } : \frac { 1 } { \sqrt { a } - \sqrt { b } } = a - b
# V = x ^ { 3 }
# V = x ^ { 3 }
# \sqrt [ 3 ] { 125 } - \sqrt [ 3 ] { 8 } - 2 \sqrt [ 3 ] { 27 }
# \sqrt [ 3 ] { 125 } - \sqrt [ 3 ] { 54 } \cdot \sqrt [ 3 ] { 4 }
# 5 \sqrt [ 3 ] { 512 } - 19
# 18 - \sqrt [ 3 ] { 729 }
# \sqrt { 3 x - 2 }
# \sqrt { \frac { 2 } { x - 2 } }
# \sqrt { - 2 x } + \sqrt { \frac { 3 } { x + 2 } }
# 2 m ^ { 3 } /
# m ^ { 3 }
# 28 ^ { \circ }
# 30 ^ { \circ }
# 32 ^ { \circ }
# 30 ^ { \circ }
# y = 2 x - 7
# y = - 5 x + 2
# y = a x + 2
# y = - 2 x + b
# x = 1 + \sqrt { 3 }
# y = \sqrt { 3 }
# y = x , y = x \hat { a } \epsilon ^ { 4 } 3 , y = - 2 x , y = - 2 x + 1
# y = - x
# y = 2 x + 3
# y = 2 x + 3
# y = \sqrt { 3 } x
# y = x + 3 , y = - x + 3
# 2 x + y = 1
# 2 x + y = 1 \Leftrightarrow y = 1 - 2 x
# y = 1 - 2 x
# \left\{ \begin{array} { l } { 2 x - 4 y = 0 } \\ { x + 3 y = 0 } \end{array} \right.
# \left\{ \begin{array} { l } { 3 x + y = 1 } \\ { 6 x + 2 y = 2 } \end{array} \right.
# \left\{ \begin{array} { l } { 2 x - y = - 1 } \\ { x - y = 2 } \end{array} \right.
# \left\{ \begin{array} { l } { x + 2 y = - 2 } \\ { 2 x + 4 y = 1 } \end{array} \right.
# \left\{ \begin{array} { l } { x + y = - 3 } \\ { 2 x + 2 y = - 6 } \end{array} \right.
# \left\{ \begin{array} { l } { x - 2 y = 1 } \\ { 2 x - 4 y = 2 } \end{array} \right.
# \left\{ \begin{array} { l } { x - y = 0 } \\ { x + y = 2 } \end{array} \right.
# \left\{ \begin{array} { l } { x + 2 y = 3 } \\ { 2 x + y = 3 } \end{array} \right.
# \left\{ \begin{array} { l } { x - 2 y = 1 } \\ { 3 x - 6 y = 3 } \end{array} \right.
# \ldots x = \ldots \Leftrightarrow x = \ldots
# \left\{ \begin{array} { l } { - 2 x + 15 y = - 32 } \\ { 7 x - 5 y = 17 } \end{array} \right.
# \left\{ \begin{array} { l } { a x - y = 2 } \\ { b x + a y = 1 } \end{array} \right.
# \left\{ \begin{array} { l } { 5 x - 6 y = - 32 } \\ { 3 x + 6 y = 48 } \end{array} \right.
# \left\{ \begin{array} { l } { 2 x + 5 y = 17 } \\ { 6 x - 5 y = - 9 } \end{array} \right.
# \left\{ \begin{array} { l } { 2 x - 3 y = 61 } \\ { 2 x + y = - 7 } \end{array} \right.
# \left\{ \begin{array} { l } { 2 x + 18 y = - 9 } \\ { 4 x + 18 y = - 27 } \end{array} \right.
# \left\{ \begin{array} { l } { 4 x + 5 y = 15 } \\ { 6 x - 4 y = 11 } \end{array} \right.
# \left\{ \begin{array} { l } { 3 x - 2 y = 10 } \\ { 2 x + 3 y = - 2 } \end{array} \right.
# \left\{ \begin{array}{l}y - \dfrac{x}{2} = 2\\\\dfrac{3}{2}x + y = 42\end{array} \right.
# \left\{ \begin{array}{l}\dfrac{2}{3}x - y = 70\\\\dfrac{1}{3}x - \dfrac{2}{3}y = 43\end{array} \right.
# x = 4
# \left\{ \begin{array} { l } { 5 x - 10 y = 50 } \\ { m x + 10 y = 6 } \end{array} \right.
# \frac { 2 } { x } + \frac { \dots } { \dots } = 1
# \left\{ \begin{array}{l}......................\\.....................\end{array} \right.
# a = \frac { 1 } { x } , b = \frac { 1 } { y }
# \left\{ \begin{array} { l } { a x + b y = c } \\ { a ^ { \prime } x + b ^ { \prime } y = c } \end{array} \right.
# \frac { a } { a ^ { \prime } } \neq \frac { b } { b ^ { \prime } }
# \frac { a } { a ^ { \prime } } = \vec { b ^ { \prime } } \neq \frac { c } { c ^ { \prime } }
# \frac { a } { a ^ { \prime } } = \frac { b } { b ^ { \prime } } = \frac { c } { c }
# \frac { 1 } { 4 }
# y = 2 x ^ { 2 } , y = - 3 x ^ { 2 } , y = 4 x ^ { 2 }
# y = x ^ { 2 } , y = \frac { 1 } { 2 } x ^ { 2 } , y = - \frac { 1 } { 2 } x ^ { 2 }
# y = 2 x ^ { 2 }
# y = - \frac { 1 } { 4 } x ^ { 2 }
# y = x ^ { 2 }
# y = 2 x + 3
# y = m x ^ { 2 }
# y = x + 1
# y = \frac { x ^ { 2 } } { 4 }
# y = - x + 3
# 2 x ^ { 2 } + \frac { 1 } { 4 } = 0
# x ^ { 2 } + 5 x - 6 = 0
# 3 \sqrt { 7 } x ^ { 2 } = 4 x
# - 7 x ^ { 2 } = 0
# 5 x = 12
# h = 0
# S _ { 1 } = 105 c m ^ { 2 }
# S _ { A R C } = 22 c m ^ { 2 }
# {S_{MNPQ}} = 114c{m^2}
# x ^ { 2 } + 2 x - m = 0
# 2 x ^ { 2 } + 3 x + m - 1 = 0
# 2 x ^ { 2 } - 2 x + m = 0
# x ^ { 2 } + 3 m x - m + 2 = 0
# x ^ { 2 } + 2 x + 5 = 0
# x ^ { 2 } - 3 x - 7 = 0
# S = x _ { 1 } + x _ { 2 }
# P = x _ { 1 } x _ { 2 }
# A = x _ { 1 } ^ { 2 } + x _ { 2 } ^ { 2 }
# B = | x _ { 1 } - x _ { 2 } |
# C = \frac { 1 } { x _ { 1 } - 1 } + \frac { 1 } { x _ { 2 } - 1 }
# E = x _ { 1 } ^ { 3 } + x _ { 2 } ^ { 3 }
# F = x _ { 1 } ^ { 4 } + x _ { 2 } ^ { 4 }
# x ^ { 4 } - 5 x ^ { 2 } + 4 = 0
# t = x ^ { 2 }
# t > 0
# 60 ^ { \circ }
# 60 ^ { \circ }
# 90 ^ { \circ }
# 37,5 c m ^ { 2 } , A B < A C
# 0 ^ { o } = \frac { 1 } { 2 }
# ^ { o } \operatorname { cot } 60 ^ { \circ }
# O A M = \frac { 3 } { 4 }
# x ^ { 2 } = 2
# x ^ { 2 } = 3
# x ^ { 2 } = 3,5
# x = 4,12
# \sqrt { x ^ { 2 } } = 7
# \sqrt { x ^ { 2 } } = 1 - 8
# \sqrt { 4 x ^ { 2 } } = 6
# \sqrt { 9 x ^ { 2 } } = | - 12
# \sqrt { 16 x } = 8
# \sqrt { 4 x } = \sqrt { 5 }
# \sqrt { 25 + 9 }
# \sqrt { 25 } + \sqrt { 9 }
# a > 0
# b > 0
# \sqrt { a + b } < \sqrt { a } + \sqrt { b }
# \sqrt { \frac { 226 } { 256 } }
# \sqrt { 0,0196 }
# \frac { \sqrt { 2 } } { \sqrt { 18 } }
# \frac { \sqrt { 15 } } { \sqrt { 735 } }
# \frac { \sqrt { 12500 } } { \sqrt { 500 } }
# \frac { \sqrt { 6 ^ { 5 } } } { \sqrt { 2 ^ { 3 } \cdot 3 ^ { 5 } } }
# \sqrt { 25 - 16 }
# \sqrt { 25 } - \sqrt { 16 }
# a > b > 0
# \sqrt { a } - \sqrt { b } < \sqrt { a - b }
# \sqrt { 2 } + \sqrt { 8 } + \sqrt { 50 }
# 4 \sqrt { 3 } + \sqrt { 27 } - \sqrt { 45 } + \sqrt { 5 }
# \sqrt { \frac { a } { b } } , \frac { a } { b } \sqrt { \frac { b } { a } } , \sqrt { \frac { 1 } { b } + b ^ { 2 } } ; \quad \sqrt { \frac { 9 a ^ { 3 } } { 36 b } } ; 3 x y \sqrt { \frac { 2 } { x y } }
# \frac { 2 + \sqrt { 2 } } { 1 + \sqrt { 2 } } \frac { \sqrt { 15 } - \sqrt { 5 } } { 1 - \sqrt { 3 } } ; \frac { 2 \sqrt { 3 } - \sqrt { 6 } } { \sqrt { 8 } - 2 }
# \frac { a - \sqrt { a } } { 1 - \sqrt { a } } , \frac { p - 2 \sqrt { p } } { \sqrt { p } - 2 }
# a , b , x , y
# a b + b \sqrt { a } + \sqrt { a } + 1
# \sqrt { x ^ { 3 } } - \sqrt { y ^ { 3 } } + \sqrt { x ^ { 2 } y } - \sqrt { x y ^ { 2 } }
# \sqrt { \frac { a } { b } } + \sqrt { a b } + \frac { a } { b } \sqrt { \frac { b } { a } }
# a > 0
# b > 0
# \sqrt { \frac { m } { 1 - 2 x + x ^ { 2 } } } \sqrt { \frac { 4 m - 8 m x + 4 m ^ { 2 } } { 81 } }
# m > 0
# x \neq 1
# \frac { 1 } { 125 }
# y = \sqrt { 3 x }
# y = \frac { m + 1 } { m - 1 } x + 3,5
# y = 2 x ; y = 2 x + 5 ; y = - 3 x
# y = - \frac { 2 } { 3 } x + 5
# O A B C
# O A B C
# y = m x + 3
# A O B = A O x - B O x
# a , b
# x ^ { 2 } = a b
# A B C D
# \frac { 1 } { D I ^ { 2 } } + \frac { 1 } { D K ^ { 2 } }
# 34 ^ { \circ }
# 34 ^ { \circ }
# \operatorname { sin } 40 ^ { \circ } 12 ^ { \prime }
# \operatorname { oss } 2 ^ { \circ } 54 ^ { \circ }
# 3 ^ { \circ } 36 ^ { \prime }
# \operatorname { cot } 25 ^ { \circ } 18 ^ { \prime }
# \operatorname { sin } x = 0,3495
# \operatorname { cos } x = 0,5427
# \operatorname { tan } x = 1,5142
# \operatorname { cot } x = 3,163
# \operatorname { tan } 25 ^ { \circ }
# \operatorname { sin } 25 ^ { \circ }
# + 32 ^ { \circ }
# 32 ^ { \circ }
# \operatorname { tan } 45 ^ { \circ }
# 45 ^ { \circ }
# 34 ^ { \circ }
# \left. \begin{array} { c } { \wedge } \\ { O K H } \end{array} \right.
# \left. \begin{array} { c } { \wedge } \\ { O H K } \end{array} \right.
# x A y
# B , C
# 5 c m
# 8 c m
# A I = 1 c m
# C D = A B
# O C / / O ^ { \prime } D
# O O ^ { \prime } = d , R > r
# d , R , r
# d > R + r
# d = R - r
# A C = C D
# A C = B D
# B A C = 9 0
# O I O ^ { \prime }
# O A = 9 c m , O ^ { \prime } A = 4 c m
# y = \frac { 1 } { 3 } x ^ { 2 }
# y = - x + 6
# a x ^ { 2 } + b x + c = 0
# a , b , c
# 5 x ^ { 2 } + 2 x = 4 - x
# \frac { 3 } { 5 } x ^ { 2 } + 2 x - 7 = 3 x + 2
# 2 x ^ { 2 } + x - \sqrt { 3 } = \sqrt { 3 } x + 1
# a , b , c
# \hat { a } ^ { \wedge } +
# 7 x ^ { 2 } - 2 x + 3 = 0
# 5 x ^ { 2 } + 2 \sqrt { 10 x } + 2 = 0
# \frac { 1 } { 2 } x ^ { 2 } + 7 x + 3 = 0
# 7 x ^ { 2 } - 1,2 x - 2,1 = 0
# a + b + c = 0
# a - b + c = 0
# 35 x ^ { 2 } - 37 x + 2 = 0
# 7 x ^ { 2 } + 500 x - 507 = 0
# x ^ { 2 } - 49 x - 50 = 0
# 4321 x ^ { 2 } + 21 x - 4300 = 0
# u + v = 32 , u v = 231
# u + v = - 8 , u v = - 105
# u + v = 2 , u v = 9
# 5 x ^ { 2 } - 1,6 x + 0,1 = 0
# y = \frac { 1 } { 4 } x ^ { 2 }
# y = - \frac { 1 } { 4 } x ^ { 2 }
# y = \frac { 1 } { 4 } x ^ { 2 }
# y = - \frac { 1 } { 4 } x ^ { 2 }
# \left. \begin{array} { c } { \wedge } \\ { A M B } \end{array} \right.
# O A , O B
# A B C
# A , B , C
# OA, OB, OC
# A , B , C
# A , B , C
# P A Q
# P B Q
# P C Q
# C B A = D B A
# M A B
# M T ^ { 2 } = M A \cdot M B
# M , N
# A E H
# A C , C D , D B
# \left. \begin{array} { r } { A C } \\ { s \ddot { A } \cdot \square } \end{array} \right.
# A E B = B T C
# B C T ^ { \wedge }
# A B C
# A M N
# \hat { A } + B S M = 2 C M N
# A B C
# P , Q , R
# B C , C A , A B
# A , B , C
# A P \perp Q R
# C P I
# A B C
# A , B
# M I = 2 M B
# \left. \begin{array} { c } { \wedge } \\ { A I B } \end{array} \right.
# I , O
# A B C
# \hat { A } = 60 ^ { \circ }
# B B ^ { \prime }
# C C ^ { \prime }
# C , O , H , I
# A B C D
# Q R / / S T
# B , C , D , A
# A B C D
# 1 c m
# A E F G H
# A m B
# A O B
# A B C D
# A B = 40 m
# A D = 30 m
# A , B
# A m B
# 66 ^ { \circ }
# A m B
# A O B
# A m B
# A C B
# A B t
# A D B
# \left. \begin{array} { c } { \wedge } \\ { A D B } \end{array} \right.
# \left. \begin{array} { c } { \wedge } \\ { A C B } \end{array} \right.
# A E B
# \left. \begin{array} { c } { \wedge } \\ { A E B } \end{array} \right.
# \left. \begin{array} { c } { \wedge } \\ { A C B } \end{array} \right.
# A , B , C
# 120 ^ { 0 }
# 8 c m
# \frac { 16 } { c m }
# 4 c m
# \frac { 16 } { 5 }
# a , b
# 1 / 0
# a , b , l
# 113 ^ { \frac { 1 } { 7 } }
# \pi = \frac { 22 } { 7 }
# 2 c m
# 3 c m
# 5 c m
# 6 c m
# r C m
# 2 r c m
# \sqrt { 100 } = 10
# \sqrt { 100 } = \pm 10
# M = \sqrt { 3 - 2 \sqrt { 2 } } - \sqrt { 6 + 4 \sqrt { 2 } }
# N = \sqrt { 2 + \sqrt { 3 } } + \sqrt { 2 - \sqrt { 3 } }
# y = a x + b
# y = x + 5
# x ^ { 2 } + a x + 1 = 0
# x ^ { 2 } - x - a = 0
# A B = 4 , B C = 5 , D E = 3
# \frac { 20 } { 3 }
# A B C
# A B , B C , C A
# x + 75 ^ { 0 } , 2 x + 25 ^ { 0 } , 3 x - 22 ^ { 0 }
# A B C
# 57 ^ { 0 } 5
# 59 ^ { \circ }
# 61 ^ { 0 }
# 60 ^ { \circ }
# 120 ^ { 0 }
# A D = A C
# A B C
# B C = 4 c m
# \hat { A } = 60 ^ { \circ }
# 1 c m
# \sqrt { 9 } - \sqrt { 144 } : \sqrt { 36 } ; \sqrt { 5 ^ { 2 } - 3 ^ { 2 } }
# \sqrt { \sqrt { 81 } }
# \sqrt { 16 x ^ { 2 } } - x
# x \geq 0
# \sqrt { 25 a ^ { 2 } } - 3
# a < 0
# \sqrt { x ^ { 2 } - 6 x + 9 } - x
# x \in R
# 2 \sqrt { a ^ { 2 } }
# a < 0
# a \geq 2
# \frac { \sqrt { 27 } } { \sqrt { 3 } }
# \frac { \sqrt { 0,4 } } { \sqrt { 0,9 } }
# \frac { \sqrt { 320 } } { \sqrt { 20 } }
# \frac { \sqrt { 3 ^ { 5 } \cdot 2 ^ { 3 } } } { \sqrt { 6 ^ { 7 } } }
# \sqrt { 2 x - 5 }
# \sqrt { 2 - 3 x }
# \sqrt { x }
# \sqrt { - x }
# \sqrt { \frac { 2 x - 3 } { 5 } }
# \sqrt { \frac { 2 x - 5 } { - 3 } }
# \sqrt { \frac { 2 x + 5 } { x + 2 } }
# \sqrt { x ^ { 2 } + 1 }
# a \geq 0 , b \geq 0 , \sqrt { a ^ { 2 } b } = \sqrt { a ^ { 2 } } \cdot \sqrt { b }
# = 1 . . . | \sqrt { b } = \ldots \sqrt { b }
# \sqrt { 18 } - 2 \sqrt { 8 } = \sqrt { 3 ^ { 2 } \dots } - 2 \sqrt { \dots .2 }
# 3 \sqrt { 32 } + \sqrt { 50 }
# 3 \sqrt { 12 } - 2 \sqrt { 27 } + \sqrt { 48 }
# 3 \sqrt { 2 } = \sqrt { 3 ^ { 2 } } \cdot \sqrt { 2 } = \sqrt { \dots .2 }
# 6 \sqrt { 3 }
# \sqrt { 75 }
# \sqrt { 75 } = \sqrt { 5 ^ { 2 } .3 } = 5 \sqrt { 3 }
# 6 \sqrt { 3 } > 5 \sqrt { 3 }
# 6 \sqrt { 3 } > \sqrt { 75 }
# \sqrt { \frac { 5 } { 11 } }
# \sqrt { \frac { 2 } { 3 b ^ { 3 } } }
# b > 0
# \sqrt { \frac { 2 } { 3 } } , \sqrt { \frac { 3 } { 2 } } ; \sqrt { \frac { 3 } { 5 } } , \sqrt { \frac { 16 } { 7 } }
# _ { a } \sqrt { \frac { 3 } { a } } ; a b \sqrt { \frac { a } { b } } ; \sqrt { \frac { 4 a ^ { 3 } } { 9 b } } ; 5 x y \sqrt { \frac { 2 } { x y } }
# \frac { 1 } { \sqrt { 2 - \sqrt { 3 } } } \frac { 1 } { \sqrt { 2 + \sqrt { 3 } } }
# \sqrt { 32 - 4 \sqrt { 60 } } - \sqrt { \frac { 2 } { 4 + \sqrt { 15 } } }
# \frac { \sqrt { 3 } } { 3 - \sqrt { 3 } } + \frac { \sqrt { 6 } } { \sqrt { 6 + 3 \sqrt { 3 } } }
# \sqrt { \frac { 3 \sqrt { 3 } - 4 } { 2 \sqrt { 3 } + 1 } } \sqrt { \frac { \sqrt { 3 } + 4 } { 5 - 2 \sqrt { 3 } } }
# \sqrt { 4 + \sqrt { 15 } } - \sqrt { 4 - \sqrt { 15 } } - \sqrt { 2 - \sqrt { 3 } }
# \sqrt { 13 + 30 \sqrt { 2 + \sqrt { 9 + 4 \sqrt { 2 } } } }
# y > 0
# a > 0 , a \neq 1
# x \geq 0 , x \neq 1
# x \geq 0 , y \geq 0 , x y \neq 1
# \frac { 1 } { 125 }
# \sqrt [ 3 ] { 64 } - \sqrt [ 3 ] { - 125 } - 2 \sqrt [ 3 ] { 216 }
# \sqrt [ 3 ] { 81 } + 3 \sqrt [ 3 ] { 24 } - 2 \sqrt [ 3 ] { 375 }
# \frac { \sqrt [ 3 ] { 135 } } { \sqrt [ 3 ] { 5 } } - \sqrt [ 3 ] { 54 } \cdot \sqrt [ 3 ] { 4 }
# \sqrt [ 3 ] { 54 x y ^ { 3 } } - y \sqrt [ 3 ] { 128 x }
# \sqrt { 7 - 4 \sqrt { 3 } } - \sqrt [ 3 ] { 26 + 15 \sqrt { 3 } }
# \sqrt [ 3 ] { 345 }
# 5 \sqrt [ 3 ] { 7 }
# 7 \sqrt [ 3 ] { 5 }
# x ^ { 3 } = 64
# x ^ { 3 } = 1331
# x ^ { 3 } = - 1000
# A = 2 y - \sqrt [ 3 ] { 9 y }
# y = - 3
# B = \frac { x } { 6 } + \sqrt [ 3 ] { \frac { x } { 3 } } - 4 \sqrt [ 3 ] { y }
# x = 192 , y = 512
# A = \frac { 1 } { 2 }
# y = - 2 x + 1
# m ^ { 3 }
# 2 m ^ { 3 } /
# y = 1 - x
# y = x ^ { 2 } + 3
# y = x
# y = x + 2
# y = 3 x + 3 , y = - 2 x + 2
# 135 ^ { \circ }
# 2 x + y = 3
# 4 x - y = 1
# \left\{ \begin{array} { l } { 5 x - 3 y = 8 } \\ { 2 x - 4 y = 6 } \end{array} \right.
# \left\{ \begin{array} { l } { - 2 m x + y = 5 } \\ { x + 3 y = 1 } \end{array} \right.
# y = x ^ { 2 }
# y = 3 x - 4
# y = a x ^ { 2 }
# y = 3 x - 4
# a x ^ { 2 } + b x + c = 0
# 7 x ^ { 2 } - 5 x = 10 - 3 x
# \frac { 1 } { x _ { 1 } - 1 }
# \frac { 1 } { x _ { 2 } - 1 }
# x _ { 1 } , x _ { 2 }
# x ^ { 2 } + 3 x - 7 = 0
# x ^ { 2 } - m x + m - 2 = 0
# \frac { x _ { 1 } ^ { 2 } - 2 } { x _ { 1 } - 1 } \frac { x _ { 2 } ^ { 2 } - 2 } { x _ { 2 } - 1 } = 4
# x ^ { 2 } - m x - 1 = 0
# \frac { x _ { 1 } ^ { 2 } + x _ { 1 } - 1 } { x _ { 1 } } - \frac { x _ { 2 } ^ { 2 } + x _ { 2 } - 1 } { x _ { 2 } }
# a ^ { 2 } = b ^ { 2 } + c ^ { 2 }
# b \cdot c = a \cdot h
# \frac { 1 } { b ^ { 2 } } + \frac { 1 } { c ^ { 2 } }
# \frac { 1 } { b ^ { 2 } } + c ^ { 2 } = \frac { b ^ { 2 } + c ^ { 2 } } { b ^ { 2 } c ^ { 2 } }
# \frac { 1 } { B D ^ { 2 } } + \frac { 1 } { B E ^ { 2 } }
# 37 ^ { \circ }
# 58 ^ { \circ }
# 58 ^ { \circ }
# A B C = 45 ^ { \circ } , B H = 20 c m , H C = 21 c m

# %%
len(data_filter)
# Out:
# 1674

# %%
# define index
request_body = {
    "settings": {
        "similarity": {
            "my_bm25":{
                "type": "BM25",
                "b": 0.75,
                "k1": 1.25
            }
        }
    },
    "mappings": {
        "exam_bm25_01": {
            "properties":{
                "stt": {"type": "long", "similarity": "my_bm25"},
                "formular": {"type": "text", "similarity": "my_bm25"}
            }
        }
    }
}

# %%
# create the index
es.indices.create(index = "idx_formular_00", body = request_body)
# Out:
# {'acknowledged': True, 'index': 'idx_formular_00', 'shards_acknowledged': True}

# %%
# prepare data
bulk_data = []

for i, j in zip(data_filter, range(1, len(data) + 1)):
    data_dict = {
        "_index": "idx_formular_00",
        "_type": "exam_bm25_01",
        "_id":j,
        "_source": {
            "stt": j,
            "formular": i
        }
    }
    bulk_data.append(data_dict)

# %%
bulk_data
# Out:
# [{'_id': 1,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 2 x + 7 }', 'stt': 1},
#   '_type': 'exam_bm25_01'},
#  {'_id': 2,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { \\frac { 1 } { - 1 + x } }', 'stt': 2},
#   '_type': 'exam_bm25_01'},
#  {'_id': 3,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { - 3 x + 4 }', 'stt': 3},
#   '_type': 'exam_bm25_01'},
#  {'_id': 4,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 1 + x ^ { 2 } }', 'stt': 4},
#   '_type': 'exam_bm25_01'},
#  {'_id': 5,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 0,09.64 }', 'stt': 5},
#   '_type': 'exam_bm25_01'},
#  {'_id': 6,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 12,1.360 }', 'stt': 6},
#   '_type': 'exam_bm25_01'},
#  {'_id': 7,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 2 ^ { 2 } .3 ^ { 4 } }', 'stt': 7},
#   '_type': 'exam_bm25_01'},
#  {'_id': 8,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 0,36 a ^ { 2 } }', 'stt': 8},
#   '_type': 'exam_bm25_01'},
#  {'_id': 9,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'a < 0', 'stt': 9},
#   '_type': 'exam_bm25_01'},
#  {'_id': 10,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\hat { a } \\% _ { 0 }', 'stt': 10},
#   '_type': 'exam_bm25_01'},
#  {'_id': 11,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'a > 1', 'stt': 11},
#   '_type': 'exam_bm25_01'},
#  {'_id': 12,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 1 } { a - b }', 'stt': 12},
#   '_type': 'exam_bm25_01'},
#  {'_id': 13,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'a > b', 'stt': 13},
#   '_type': 'exam_bm25_01'},
#  {'_id': 14,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { \\frac { 289 } { 225 } }', 'stt': 14},
#   '_type': 'exam_bm25_01'},
#  {'_id': 15,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { \\frac { 14 } { 25 } }', 'stt': 15},
#   '_type': 'exam_bm25_01'},
#  {'_id': 16,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { \\frac { 0,25 } { 9 } }', 'stt': 16},
#   '_type': 'exam_bm25_01'},
#  {'_id': 17,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { \\frac { 8,1 } { 1,6 } }', 'stt': 17},
#   '_type': 'exam_bm25_01'},
#  {'_id': 18,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 4 x ^ { 2 } + 4 x + 1 } = 6', 'stt': 18},
#   '_type': 'exam_bm25_01'},
#  {'_id': 19,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 9,11 }', 'stt': 19},
#   '_type': 'exam_bm25_01'},
#  {'_id': 20,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 39,82 }', 'stt': 20},
#   '_type': 'exam_bm25_01'},
#  {'_id': 21,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 9,119 } \\approx 3,019', 'stt': 21},
#   '_type': 'exam_bm25_01'},
#  {'_id': 22,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 911,9 }', 'stt': 22},
#   '_type': 'exam_bm25_01'},
#  {'_id': 23,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 91190 }', 'stt': 23},
#   '_type': 'exam_bm25_01'},
#  {'_id': 24,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 0,09119 }', 'stt': 24},
#   '_type': 'exam_bm25_01'},
#  {'_id': 25,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 0,0009119 }', 'stt': 25},
#   '_type': 'exam_bm25_01'},
#  {'_id': 26,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 5 } { 3 \\sqrt { 8 } } ; \\frac { 2 } { \\sqrt { b } }',
#    'stt': 26},
#   '_type': 'exam_bm25_01'},
#  {'_id': 27,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 5 } { 5 - 2 \\sqrt { 3 } } ; \\frac { 2 a } { 1 - \\sqrt { a } }',
#    'stt': 27},
#   '_type': 'exam_bm25_01'},
#  {'_id': 28,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'a \\geq 0', 'stt': 28},
#   '_type': 'exam_bm25_01'},
#  {'_id': 29,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'a \\neq 1', 'stt': 29},
#   '_type': 'exam_bm25_01'},
#  {'_id': 30,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 4 } { \\sqrt { 7 } + \\sqrt { 5 } } ; \\frac { 6 a } { 2 \\sqrt { a } - \\sqrt { b } }',
#    'stt': 30},
#   '_type': 'exam_bm25_01'},
#  {'_id': 31,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 5 } { \\sqrt { 10 } } \\frac { 5 } { 2 \\sqrt { 5 } } , \\frac { 1 } { 3 \\sqrt { 20 } } , \\quad \\frac { 2 \\sqrt { 2 } + 2 } { 5 \\sqrt { 2 } } , \\frac { y + b \\cdot \\sqrt { y } } { b \\cdot \\sqrt { y } }',
#    'stt': 31},
#   '_type': 'exam_bm25_01'},
#  {'_id': 32,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B = \\sqrt { 16 x + 16 } - \\sqrt { 9 x + 9 } + \\sqrt { 4 x + 4 } + \\sqrt { x + 1 }',
#    'stt': 32},
#   '_type': 'exam_bm25_01'},
#  {'_id': 33,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x \\geq - 1', 'stt': 33},
#   '_type': 'exam_bm25_01'},
#  {'_id': 34,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '| ( 11 )', 'stt': 34},
#   '_type': 'exam_bm25_01'},
#  {'_id': 35,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'a > 0', 'stt': 35},
#   '_type': 'exam_bm25_01'},
#  {'_id': 36,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'a \\neq 1', 'stt': 36},
#   '_type': 'exam_bm25_01'},
#  {'_id': 37,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { - 9 a } - \\sqrt { 9 + 12 a + 4 a ^ { 2 } }',
#    'stt': 37},
#   '_type': 'exam_bm25_01'},
#  {'_id': 38,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'a = - 9', 'stt': 38},
#   '_type': 'exam_bm25_01'},
#  {'_id': 39,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '1 + \\frac { 3 m } { m - 2 } \\sqrt { m ^ { 2 } - 4 m + 4 }',
#    'stt': 39},
#   '_type': 'exam_bm25_01'},
#  {'_id': 40,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'm = 1,5', 'stt': 40},
#   '_type': 'exam_bm25_01'},
#  {'_id': 41,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 1 - 10 a + 25 a ^ { 2 } } - 4 a',
#    'stt': 41},
#   '_type': 'exam_bm25_01'},
#  {'_id': 42,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'a = \\sqrt { 2 }', 'stt': 42},
#   '_type': 'exam_bm25_01'},
#  {'_id': 43,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '4 x - \\sqrt { 9 x ^ { 2 } + 6 x + 1 }', 'stt': 43},
#   '_type': 'exam_bm25_01'},
#  {'_id': 44,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x = - \\sqrt { 3 }', 'stt': 44},
#   '_type': 'exam_bm25_01'},
#  {'_id': 45,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 5 } { 3 } \\sqrt { 15 x } - \\sqrt { 15 x } - 2 = \\frac { 1 } { 3 } \\sqrt { 15 x }',
#    'stt': 45},
#   '_type': 'exam_bm25_01'},
#  {'_id': 46,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = \\frac { 1 } { 2 } x + 5', 'stt': 46},
#   '_type': 'exam_bm25_01'},
#  {'_id': 47,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x = 1 + \\sqrt { 5 }', 'stt': 47},
#   '_type': 'exam_bm25_01'},
#  {'_id': 48,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = \\sqrt { 5 }', 'stt': 48},
#   '_type': 'exam_bm25_01'},
#  {'_id': 49,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = x', 'stt': 49},
#   '_type': 'exam_bm25_01'},
#  {'_id': 50,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 2 x + 2', 'stt': 50},
#   '_type': 'exam_bm25_01'},
#  {'_id': 51,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = x', 'stt': 51},
#   '_type': 'exam_bm25_01'},
#  {'_id': 52,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C', 'stt': 52},
#   '_type': 'exam_bm25_01'},
#  {'_id': 53,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = x + 1', 'stt': 53},
#   '_type': 'exam_bm25_01'},
#  {'_id': 54,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - x + 3', 'stt': 54},
#   '_type': 'exam_bm25_01'},
#  {'_id': 55,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = x + 1', 'stt': 55},
#   '_type': 'exam_bm25_01'},
#  {'_id': 56,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - x + 3', 'stt': 56},
#   '_type': 'exam_bm25_01'},
#  {'_id': 57,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A , B , C', 'stt': 57},
#   '_type': 'exam_bm25_01'},
#  {'_id': 58,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C', 'stt': 58},
#   '_type': 'exam_bm25_01'},
#  {'_id': 59,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 1,5 x + 2', 'stt': 59},
#   '_type': 'exam_bm25_01'},
#  {'_id': 60,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = x + 2', 'stt': 60},
#   '_type': 'exam_bm25_01'},
#  {'_id': 61,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 0,5 x - 3', 'stt': 61},
#   '_type': 'exam_bm25_01'},
#  {'_id': 62,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = x - 3', 'stt': 62},
#   '_type': 'exam_bm25_01'},
#  {'_id': 63,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 1,5 x - 1', 'stt': 63},
#   '_type': 'exam_bm25_01'},
#  {'_id': 64,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 0,5 x + 3', 'stt': 64},
#   '_type': 'exam_bm25_01'},
#  {'_id': 65,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C', 'stt': 65},
#   '_type': 'exam_bm25_01'},
#  {'_id': 66,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A C = 0,9 m', 'stt': 66},
#   '_type': 'exam_bm25_01'},
#  {'_id': 67,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B C = 1,2 m', 'stt': 67},
#   '_type': 'exam_bm25_01'},
#  {'_id': 68,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x = \\frac { 2 } { 3 }', 'stt': 68},
#   '_type': 'exam_bm25_01'},
#  {'_id': 69,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '= \\frac { 3 } { 4 }', 'stt': 69},
#   '_type': 'exam_bm25_01'},
#  {'_id': 70,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\alpha = \\frac { 3 } { 2 }', 'stt': 70},
#   '_type': 'exam_bm25_01'},
#  {'_id': 71,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C', 'stt': 71},
#   '_type': 'exam_bm25_01'},
#  {'_id': 72,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '( \\wedge \\operatorname { cos } B = 0 , 8 )',
#    'stt': 72},
#   '_type': 'exam_bm25_01'},
#  {'_id': 73,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C', 'stt': 73},
#   '_type': 'exam_bm25_01'},
#  {'_id': 74,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B C = 11 c n', 'stt': 74},
#   '_type': 'exam_bm25_01'},
#  {'_id': 75,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C = 38 ^ { \\circ } , A C B = 30 ^ { \\circ }',
#    'stt': 75},
#   '_type': 'exam_bm25_01'},
#  {'_id': 76,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 5 } { 3 }', 'stt': 76},
#   '_type': 'exam_bm25_01'},
#  {'_id': 77,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 5 } { 4 }', 'stt': 77},
#   '_type': 'exam_bm25_01'},
#  {'_id': 78,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 3 } { 5 }', 'stt': 78},
#   '_type': 'exam_bm25_01'},
#  {'_id': 79,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 3 } { 5 }', 'stt': 79},
#   '_type': 'exam_bm25_01'},
#  {'_id': 80,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { P R } { R S }', 'stt': 80},
#   '_type': 'exam_bm25_01'},
#  {'_id': 81,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { P R } { Q R }', 'stt': 81},
#   '_type': 'exam_bm25_01'},
#  {'_id': 82,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { P S } { S R }', 'stt': 82},
#   '_type': 'exam_bm25_01'},
#  {'_id': 83,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { S R } { Q R }', 'stt': 83},
#   '_type': 'exam_bm25_01'},
#  {'_id': 84,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 2 a } { \\sqrt { 3 } }', 'stt': 84},
#   '_type': 'exam_bm25_01'},
#  {'_id': 85,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { a } { \\sqrt { 3 } }', 'stt': 85},
#   '_type': 'exam_bm25_01'},
#  {'_id': 86,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { \\sqrt { 3 } } { 2 }', 'stt': 86},
#   '_type': 'exam_bm25_01'},
#  {'_id': 87,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 \\sqrt { 3 } a ^ { 2 }', 'stt': 87},
#   '_type': 'exam_bm25_01'},
#  {'_id': 88,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '60 ^ { \\circ }', 'stt': 88},
#   '_type': 'exam_bm25_01'},
#  {'_id': 89,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '70 ^ { 0 }', 'stt': 89},
#   '_type': 'exam_bm25_01'},
#  {'_id': 90,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B , C , D', 'stt': 90},
#   '_type': 'exam_bm25_01'},
#  {'_id': 91,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B , C , D', 'stt': 91},
#   '_type': 'exam_bm25_01'},
#  {'_id': 92,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '1 , B , C , D , E', 'stt': 92},
#   '_type': 'exam_bm25_01'},
#  {'_id': 93,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '22 c m', 'stt': 93},
#   '_type': 'exam_bm25_01'},
#  {'_id': 94,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '6 c m', 'stt': 94},
#   '_type': 'exam_bm25_01'},
#  {'_id': 95,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C', 'stt': 95},
#   '_type': 'exam_bm25_01'},
#  {'_id': 96,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B = 3 , A C = 4 , B C = 5', 'stt': 96},
#   '_type': 'exam_bm25_01'},
#  {'_id': 97,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A , B , C', 'stt': 97},
#   '_type': 'exam_bm25_01'},
#  {'_id': 98,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x A y', 'stt': 98},
#   '_type': 'exam_bm25_01'},
#  {'_id': 99,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A x , B y', 'stt': 99},
#   '_type': 'exam_bm25_01'},
#  {'_id': 100,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A x , B y', 'stt': 100},
#   '_type': 'exam_bm25_01'},
#  {'_id': 101,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\widehat {CO{\\rm{D}}} = {90^0}', 'stt': 101},
#   '_type': 'exam_bm25_01'},
#  {'_id': 102,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'C D = A C + B D', 'stt': 102},
#   '_type': 'exam_bm25_01'},
#  {'_id': 103,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A C . B D', 'stt': 103},
#   '_type': 'exam_bm25_01'},
#  {'_id': 104,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C', 'stt': 104},
#   '_type': 'exam_bm25_01'},
#  {'_id': 105,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '1 c m', 'stt': 105},
#   '_type': 'exam_bm25_01'},
#  {'_id': 106,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C', 'stt': 106},
#   '_type': 'exam_bm25_01'},
#  {'_id': 107,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '6 c m ^ { 2 }', 'stt': 107},
#   '_type': 'exam_bm25_01'},
#  {'_id': 108,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 3 } c m ^ { 2 }', 'stt': 108},
#   '_type': 'exam_bm25_01'},
#  {'_id': 109,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 3 \\sqrt { 3 } } { 4 }', 'stt': 109},
#   '_type': 'exam_bm25_01'},
#  {'_id': 110,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '3 \\sqrt { 3 } c m ^ { 2 }', 'stt': 110},
#   '_type': 'exam_bm25_01'},
#  {'_id': 111,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '1 c m', 'stt': 111},
#   '_type': 'exam_bm25_01'},
#  {'_id': 112,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '1 c m', 'stt': 112},
#   '_type': 'exam_bm25_01'},
#  {'_id': 113,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 x + y = 4', 'stt': 113},
#   '_type': 'exam_bm25_01'},
#  {'_id': 114,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '3 x + 2 y = 5', 'stt': 114},
#   '_type': 'exam_bm25_01'},
#  {'_id': 115,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left\\{ \\begin{array}{l}{ 4 x - 4 y = 2 }\\\\{ - 2 x + 2 y = - 1 }\\end{array} \\right.',
#    'stt': 115},
#   '_type': 'exam_bm25_01'},
#  {'_id': 116,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left\\{\\begin{matrix} \\dfrac{1}{3}x - y = \\dfrac{2}{3} & & \\\\ x -3y = 2 & & \\end{matrix}\\right.',
#    'stt': 116},
#   '_type': 'exam_bm25_01'},
#  {'_id': 117,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = \\frac { 1 } { 2 } x ^ { 2 } ; y = x ^ { 2 } ; y = 2 x ^ { 2 }',
#    'stt': 117},
#   '_type': 'exam_bm25_01'},
#  {'_id': 118,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A , B , C', 'stt': 118},
#   '_type': 'exam_bm25_01'},
#  {'_id': 119,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x = - 1,5', 'stt': 119},
#   '_type': 'exam_bm25_01'},
#  {'_id': 120,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A ^ { \\prime } , B ^ { \\prime } , C ^ { \\prime }',
#    'stt': 120},
#   '_type': 'exam_bm25_01'},
#  {'_id': 121,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x = 1,5', 'stt': 121},
#   '_type': 'exam_bm25_01'},
#  {'_id': 122,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'C ^ { \\prime }', 'stt': 122},
#   '_type': 'exam_bm25_01'},
#  {'_id': 123,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'a , b ^ { \\prime } , c', 'stt': 123},
#   '_type': 'exam_bm25_01'},
#  {'_id': 124,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '4 x ^ { 2 } + 4 x + 1 = 0', 'stt': 124},
#   '_type': 'exam_bm25_01'},
#  {'_id': 125,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '13852 x ^ { 2 } - 14 x + 1 = 0', 'stt': 125},
#   '_type': 'exam_bm25_01'},
#  {'_id': 126,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '5 x ^ { 2 } - 6 x + 1 = 0', 'stt': 126},
#   '_type': 'exam_bm25_01'},
#  {'_id': 127,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '- 3 x ^ { 2 } + 4 \\sqrt { 6 } x + 4 = 0',
#    'stt': 127},
#   '_type': 'exam_bm25_01'},
#  {'_id': 128,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x^2 – x – 2 = 0', 'stt': 128},
#   '_type': 'exam_bm25_01'},
#  {'_id': 129,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'u + v = 12', 'stt': 129},
#   '_type': 'exam_bm25_01'},
#  {'_id': 130,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'u v = 28', 'stt': 130},
#   '_type': 'exam_bm25_01'},
#  {'_id': 131,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'u > v', 'stt': 131},
#   '_type': 'exam_bm25_01'},
#  {'_id': 132,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'u + v = 3 ; u v = 6', 'stt': 132},
#   '_type': 'exam_bm25_01'},
#  {'_id': 133,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A O B', 'stt': 133},
#   '_type': 'exam_bm25_01'},
#  {'_id': 134,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A O C , A O ^ { \\prime } D', 'stt': 134},
#   '_type': 'exam_bm25_01'},
#  {'_id': 135,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B C , B D', 'stt': 135},
#   '_type': 'exam_bm25_01'},
#  {'_id': 136,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'E B D', 'stt': 136},
#   '_type': 'exam_bm25_01'},
#  {'_id': 137,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'E B D', 'stt': 137},
#   '_type': 'exam_bm25_01'},
#  {'_id': 138,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'S _ { A }', 'stt': 138},
#   '_type': 'exam_bm25_01'},
#  {'_id': 139,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'M , N', 'stt': 139},
#   '_type': 'exam_bm25_01'},
#  {'_id': 140,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'M B N', 'stt': 140},
#   '_type': 'exam_bm25_01'},
#  {'_id': 141,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B = 40', 'stt': 141},
#   '_type': 'exam_bm25_01'},
#  {'_id': 142,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'M K = 3', 'stt': 142},
#   '_type': 'exam_bm25_01'},
#  {'_id': 143,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A M B', 'stt': 143},
#   '_type': 'exam_bm25_01'},
#  {'_id': 144,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B C = R', 'stt': 144},
#   '_type': 'exam_bm25_01'},
#  {'_id': 145,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B , C', 'stt': 145},
#   '_type': 'exam_bm25_01'},
#  {'_id': 146,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C , B A C', 'stt': 146},
#   '_type': 'exam_bm25_01'},
#  {'_id': 147,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A S C - M C', 'stt': 147},
#   '_type': 'exam_bm25_01'},
#  {'_id': 148,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C', 'stt': 148},
#   '_type': 'exam_bm25_01'},
#  {'_id': 149,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B C = 6 c m', 'stt': 149},
#   '_type': 'exam_bm25_01'},
#  {'_id': 150,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\hat { A } = 40 ^ { \\circ }', 'stt': 150},
#   '_type': 'exam_bm25_01'},
#  {'_id': 151,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A H = 4 c m', 'stt': 151},
#   '_type': 'exam_bm25_01'},
#  {'_id': 152,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C D', 'stt': 152},
#   '_type': 'exam_bm25_01'},
#  {'_id': 153,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left. \\begin{array} { r } { A B } \\\\ { S \\ddot { A } \\cdot \\square } \\end{array} \\right.',
#    'stt': 153},
#   '_type': 'exam_bm25_01'},
#  {'_id': 154,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '60 ^ { \\circ }', 'stt': 154},
#   '_type': 'exam_bm25_01'},
#  {'_id': 155,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left. \\begin{array} { r } { B C } \\\\ { s \\ddot { A } \\cdot \\square } \\end{array} \\right.',
#    'stt': 155},
#   '_type': 'exam_bm25_01'},
#  {'_id': 156,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '90 ^ { 0 }', 'stt': 156},
#   '_type': 'exam_bm25_01'},
#  {'_id': 157,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left. \\begin{array} { c } { C D } \\\\ { s \\ddot { A } \\cdot \\square } \\end{array} \\right.',
#    'stt': 157},
#   '_type': 'exam_bm25_01'},
#  {'_id': 158,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '120 ^ { 0 }', 'stt': 158},
#   '_type': 'exam_bm25_01'},
#  {'_id': 159,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C D', 'stt': 159},
#   '_type': 'exam_bm25_01'},
#  {'_id': 160,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C D', 'stt': 160},
#   '_type': 'exam_bm25_01'},
#  {'_id': 161,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C D', 'stt': 161},
#   '_type': 'exam_bm25_01'},
#  {'_id': 162,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '60 ^ { \\circ }', 'stt': 162},
#   '_type': 'exam_bm25_01'},
#  {'_id': 163,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 d m', 'stt': 163},
#   '_type': 'exam_bm25_01'},
#  {'_id': 164,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C D', 'stt': 164},
#   '_type': 'exam_bm25_01'},
#  {'_id': 165,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B = 10 c m', 'stt': 165},
#   '_type': 'exam_bm25_01'},
#  {'_id': 166,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B C = 4 c m', 'stt': 166},
#   '_type': 'exam_bm25_01'},
#  {'_id': 167,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '7 c m', 'stt': 167},
#   '_type': 'exam_bm25_01'},
#  {'_id': 168,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '352 cm ^ { 2 }', 'stt': 168},
#   '_type': 'exam_bm25_01'},
#  {'_id': 169,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '3,2 c m', 'stt': 169},
#   '_type': 'exam_bm25_01'},
#  {'_id': 170,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '1,8 c m', 'stt': 170},
#   '_type': 'exam_bm25_01'},
#  {'_id': 171,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2,1 c m', 'stt': 171},
#   '_type': 'exam_bm25_01'},
#  {'_id': 172,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '12,8 c m ^ { 2 }', 'stt': 172},
#   '_type': 'exam_bm25_01'},
#  {'_id': 173,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '8,5 m m', 'stt': 173},
#   '_type': 'exam_bm25_01'},
#  {'_id': 174,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 c m', 'stt': 174},
#   '_type': 'exam_bm25_01'},
#  {'_id': 175,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '5 c m', 'stt': 175},
#   '_type': 'exam_bm25_01'},
#  {'_id': 176,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '8 m m', 'stt': 176},
#   '_type': 'exam_bm25_01'},
#  {'_id': 177,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C D', 'stt': 177},
#   '_type': 'exam_bm25_01'},
#  {'_id': 178,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '120 ^ { \\circ }', 'stt': 178},
#   '_type': 'exam_bm25_01'},
#  {'_id': 179,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { \\sqrt { 2 } } { 4 }', 'stt': 179},
#   '_type': 'exam_bm25_01'},
#  {'_id': 180,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { \\sqrt { 2 } } { 2 }', 'stt': 180},
#   '_type': 'exam_bm25_01'},
#  {'_id': 181,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 2 }', 'stt': 181},
#   '_type': 'exam_bm25_01'},
#  {'_id': 182,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 2 }', 'stt': 182},
#   '_type': 'exam_bm25_01'},
#  {'_id': 183,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A A ^ { \\prime }', 'stt': 183},
#   '_type': 'exam_bm25_01'},
#  {'_id': 184,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 2 + \\sqrt { x } } = 3', 'stt': 184},
#   '_type': 'exam_bm25_01'},
#  {'_id': 185,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 7 }', 'stt': 185},
#   '_type': 'exam_bm25_01'},
#  {'_id': 186,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 2 x + n', 'stt': 186},
#   '_type': 'exam_bm25_01'},
#  {'_id': 187,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C', 'stt': 187},
#   '_type': 'exam_bm25_01'},
#  {'_id': 188,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sin {\\rm{A}} = {2 \\over 3}', 'stt': 188},
#   '_type': 'exam_bm25_01'},
#  {'_id': 189,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { tan } B', 'stt': 189},
#   '_type': 'exam_bm25_01'},
#  {'_id': 190,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 3 } { 5 }', 'stt': 190},
#   '_type': 'exam_bm25_01'},
#  {'_id': 191,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { \\sqrt { 5 } } { 3 }', 'stt': 191},
#   '_type': 'exam_bm25_01'},
#  {'_id': 192,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 2 } { \\sqrt { 5 } }', 'stt': 192},
#   '_type': 'exam_bm25_01'},
#  {'_id': 193,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { \\sqrt { 5 } } { 2 }', 'stt': 193},
#   '_type': 'exam_bm25_01'},
#  {'_id': 194,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C', 'stt': 194},
#   '_type': 'exam_bm25_01'},
#  {'_id': 195,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '( O ^ { \\prime }', 'stt': 195},
#   '_type': 'exam_bm25_01'},
#  {'_id': 196,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'C D = B D = O ^ { \\prime } D', 'stt': 196},
#   '_type': 'exam_bm25_01'},
#  {'_id': 197,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A O = C O = O D', 'stt': 197},
#   '_type': 'exam_bm25_01'},
#  {'_id': 198,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'C D = C O = B D', 'stt': 198},
#   '_type': 'exam_bm25_01'},
#  {'_id': 199,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'C D = O D = B D', 'stt': 199},
#   '_type': 'exam_bm25_01'},
#  {'_id': 200,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'O O ^ { \\prime }', 'stt': 200},
#   '_type': 'exam_bm25_01'},
#  {'_id': 201,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '3 c m', 'stt': 201},
#   '_type': 'exam_bm25_01'},
#  {'_id': 202,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 c m', 'stt': 202},
#   '_type': 'exam_bm25_01'},
#  {'_id': 203,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 8,1 } \\cdot \\sqrt { 100 } \\cdot \\sqrt { 0,9 }',
#    'stt': 203},
#   '_type': 'exam_bm25_01'},
#  {'_id': 204,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { \\frac { 25 } { 64 } }', 'stt': 204},
#   '_type': 'exam_bm25_01'},
#  {'_id': 205,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { \\frac { 16 } { 25 } : \\frac { 49 } { 64 } }',
#    'stt': 205},
#   '_type': 'exam_bm25_01'},
#  {'_id': 206,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { \\sqrt { 63 } } { \\sqrt { 7 } }',
#    'stt': 206},
#   '_type': 'exam_bm25_01'},
#  {'_id': 207,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 8 ^ { 2 } + 6 ^ { 2 } }', 'stt': 207},
#   '_type': 'exam_bm25_01'},
#  {'_id': 208,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { x ^ { 2 } } = 5', 'stt': 208},
#   '_type': 'exam_bm25_01'},
#  {'_id': 209,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { x ^ { 2 } } = | - 2', 'stt': 209},
#   '_type': 'exam_bm25_01'},
#  {'_id': 210,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 16 x ^ { 2 } } = 3', 'stt': 210},
#   '_type': 'exam_bm25_01'},
#  {'_id': 211,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 9 x ^ { 2 } } = | - 2', 'stt': 211},
#   '_type': 'exam_bm25_01'},
#  {'_id': 212,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 16.9 }', 'stt': 212},
#   '_type': 'exam_bm25_01'},
#  {'_id': 213,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 160.2,5 }', 'stt': 213},
#   '_type': 'exam_bm25_01'},
#  {'_id': 214,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 0,9.10 ^ { 2 } .3,6 }', 'stt': 214},
#   '_type': 'exam_bm25_01'},
#  {'_id': 215,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 2 x - 1 } = 5', 'stt': 215},
#   '_type': 'exam_bm25_01'},
#  {'_id': 216,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 2 x - 1 } = | - 3', 'stt': 216},
#   '_type': 'exam_bm25_01'},
#  {'_id': 217,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 50 }', 'stt': 217},
#   '_type': 'exam_bm25_01'},
#  {'_id': 218,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 27 }', 'stt': 218},
#   '_type': 'exam_bm25_01'},
#  {'_id': 219,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '5 \\sqrt { 3 }', 'stt': 219},
#   '_type': 'exam_bm25_01'},
#  {'_id': 220,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 48 }', 'stt': 220},
#   '_type': 'exam_bm25_01'},
#  {'_id': 221,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '3 \\sqrt { 5 }', 'stt': 221},
#   '_type': 'exam_bm25_01'},
#  {'_id': 222,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 5 } { 3 \\sqrt { 7 } }', 'stt': 222},
#   '_type': 'exam_bm25_01'},
#  {'_id': 223,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 4 } { \\sqrt { 5 } - 3 }', 'stt': 223},
#   '_type': 'exam_bm25_01'},
#  {'_id': 224,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { a } { \\sqrt { a } + 1 }', 'stt': 224},
#   '_type': 'exam_bm25_01'},
#  {'_id': 225,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 18 } - 2 \\sqrt { 32 } + 3 \\sqrt { 50 } - 4 \\sqrt { 8 }',
#    'stt': 225},
#   '_type': 'exam_bm25_01'},
#  {'_id': 226,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '3 \\sqrt { 27 } + \\sqrt { 75 } - 3 \\sqrt { 48 } - 4 \\sqrt { 12 }',
#    'stt': 226},
#   '_type': 'exam_bm25_01'},
#  {'_id': 227,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 \\sqrt { 5 } - 2 \\sqrt { 108 } + 3 \\sqrt { 20 } + 5 \\sqrt { 27 }',
#    'stt': 227},
#   '_type': 'exam_bm25_01'},
#  {'_id': 228,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 7 } { \\sqrt { 3 } } \\frac { 3 } { 2 \\sqrt { 5 } } ; \\frac { 5 } { 3 \\sqrt { 12 } } , \\frac { 2 } { 3 \\sqrt { 20 } }',
#    'stt': 228},
#   '_type': 'exam_bm25_01'},
#  {'_id': 229,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { \\sqrt { 3 } + 3 } { 5 \\sqrt { 3 } } : \\frac { 7 - \\sqrt { 7 } } { \\sqrt { 7 } - 1 }',
#    'stt': 229},
#   '_type': 'exam_bm25_01'},
#  {'_id': 230,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 5 } { \\sqrt { 5 } + 2 } , \\frac { 3 } { \\sqrt { 3 } - 1 } , \\frac { 2 } { \\sqrt { 5 } + \\sqrt { 3 } }',
#    'stt': 230},
#   '_type': 'exam_bm25_01'},
#  {'_id': 231,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { \\sqrt { 5 } + 2 } { \\sqrt { 5 } - 2 } , \\frac { \\sqrt { 7 } - \\sqrt { 5 } } { \\sqrt { 7 } + \\sqrt { 5 } }',
#    'stt': 231},
#   '_type': 'exam_bm25_01'},
#  {'_id': 232,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { y + a \\sqrt { y } } { a \\sqrt { y } } , \\frac { b - \\sqrt { b } } { \\sqrt { b } - 1 }',
#    'stt': 232},
#   '_type': 'exam_bm25_01'},
#  {'_id': 233,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { b } { 5 + \\sqrt { b } } _ { : } \\frac { p } { 2 \\sqrt { p } - 1 } , \\frac { \\sqrt { a } + \\sqrt { b } } { \\sqrt { a } - \\sqrt { b } }',
#    'stt': 233},
#   '_type': 'exam_bm25_01'},
#  {'_id': 234,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 3 + 2 \\sqrt { 3 } } { \\sqrt { 3 } } - \\frac { 2 \\sqrt { 3 } + \\sqrt { 15 } } { \\sqrt { 5 } + 2 }',
#    'stt': 234},
#   '_type': 'exam_bm25_01'},
#  {'_id': 235,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 5 \\sqrt { 2 } - 2 \\sqrt { 5 } } { \\sqrt { 10 } } - \\frac { 3 } { \\sqrt { 5 } - \\sqrt { 2 } }',
#    'stt': 235},
#   '_type': 'exam_bm25_01'},
#  {'_id': 236,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { \\sqrt { 15 } - \\sqrt { 12 } } { \\sqrt { 5 } - 2 } = \\frac { 1 } { 2 - \\sqrt { 3 } }',
#    'stt': 236},
#   '_type': 'exam_bm25_01'},
#  {'_id': 237,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 4 } { 1 + \\sqrt { 3 } } \\frac { \\sqrt { 3 } - 1 } { \\sqrt { 3 } + 1 }',
#    'stt': 237},
#   '_type': 'exam_bm25_01'},
#  {'_id': 238,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 4 - 2 \\sqrt { 3 } } + \\sqrt { \\frac { 2 } { 2 - \\sqrt { 3 } } } - \\sqrt { 27 }',
#    'stt': 238},
#   '_type': 'exam_bm25_01'},
#  {'_id': 239,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { \\sqrt { 2 } } { \\sqrt { \\sqrt { 2 } + 1 } - 1 } \\frac { \\sqrt { 2 } } { \\sqrt { \\sqrt { 2 } + 1 } + 1 }',
#    'stt': 239},
#   '_type': 'exam_bm25_01'},
#  {'_id': 240,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '- \\frac { 1 } { 2 } \\sqrt { 108 } - \\frac { 1 } { 15 } \\sqrt { 75 } - 22 \\sqrt { 363 } + \\sqrt { 12 }',
#    'stt': 240},
#   '_type': 'exam_bm25_01'},
#  {'_id': 241,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 \\sqrt { \\frac { 27 } { 2 } } - \\sqrt { \\frac { 48 } { 9 } } - \\frac { 2 } { 5 } \\sqrt { \\frac { 75 } { 18 } }',
#    'stt': 241},
#   '_type': 'exam_bm25_01'},
#  {'_id': 242,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 y \\sqrt { 45 } + 3 \\sqrt { 20 y ^ { 2 } }',
#    'stt': 242},
#   '_type': 'exam_bm25_01'},
#  {'_id': 243,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '3 x \\sqrt { 72 x } - 9 \\sqrt { 50 x ^ { 3 } }',
#    'stt': 243},
#   '_type': 'exam_bm25_01'},
#  {'_id': 244,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x \\geq 0', 'stt': 244},
#   '_type': 'exam_bm25_01'},
#  {'_id': 245,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 9 - 4 \\sqrt { 5 } } - \\sqrt { 14 + 6 \\sqrt { 5 } }',
#    'stt': 245},
#   '_type': 'exam_bm25_01'},
#  {'_id': 246,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 13 - \\sqrt { 160 } } - \\sqrt { 53 + 4 \\sqrt { 60 } }',
#    'stt': 246},
#   '_type': 'exam_bm25_01'},
#  {'_id': 247,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt [ 3 ] { 3 x + 4 } = 4', 'stt': 247},
#   '_type': 'exam_bm25_01'},
#  {'_id': 248,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '3 + \\sqrt [ 3 ] { 5 x + 3 } = 0', 'stt': 248},
#   '_type': 'exam_bm25_01'},
#  {'_id': 249,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { \\sqrt { x } + 7 x + 13 } { x + 3 \\sqrt { x } - 10 } + \\frac { \\sqrt { x } + 5 } { 2 - \\sqrt { x } } - \\frac { \\sqrt { x } - 4 } { \\sqrt { x } + 5 }',
#    'stt': 249},
#   '_type': 'exam_bm25_01'},
#  {'_id': 250,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = x', 'stt': 250},
#   '_type': 'exam_bm25_01'},
#  {'_id': 251,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x \\neq 0', 'stt': 251},
#   '_type': 'exam_bm25_01'},
#  {'_id': 252,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x = 2', 'stt': 252},
#   '_type': 'exam_bm25_01'},
#  {'_id': 253,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 6', 'stt': 253},
#   '_type': 'exam_bm25_01'},
#  {'_id': 254,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'c m ^ { 3 }', 'stt': 254},
#   '_type': 'exam_bm25_01'},
#  {'_id': 255,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 3 x', 'stt': 255},
#   '_type': 'exam_bm25_01'},
#  {'_id': 256,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '= - 60000 c + 10000000', 'stt': 256},
#   '_type': 'exam_bm25_01'},
#  {'_id': 257,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 5 x - 3', 'stt': 257},
#   '_type': 'exam_bm25_01'},
#  {'_id': 258,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = \\frac { 2 } { x } + 4', 'stt': 258},
#   '_type': 'exam_bm25_01'},
#  {'_id': 259,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 3 x ^ { 2 } + 1', 'stt': 259},
#   '_type': 'exam_bm25_01'},
#  {'_id': 260,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = a x + 4', 'stt': 260},
#   '_type': 'exam_bm25_01'},
#  {'_id': 261,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - 3 x - 1', 'stt': 261},
#   '_type': 'exam_bm25_01'},
#  {'_id': 262,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = a x - 2', 'stt': 262},
#   '_type': 'exam_bm25_01'},
#  {'_id': 263,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 3 x + b', 'stt': 263},
#   '_type': 'exam_bm25_01'},
#  {'_id': 264,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 2 x - 3', 'stt': 264},
#   '_type': 'exam_bm25_01'},
#  {'_id': 265,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '0 x + 3 y = 3', 'stt': 265},
#   '_type': 'exam_bm25_01'},
#  {'_id': 266,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '. . x + \\ldots y = 45', 'stt': 266},
#   '_type': 'exam_bm25_01'},
#  {'_id': 267,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\ldots x + \\ldots y = 375', 'stt': 267},
#   '_type': 'exam_bm25_01'},
#  {'_id': 268,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left\\{ \\begin{array} { l } { \\dots x + \\ldots y = 45 } \\\\ { \\dots x + \\ldots y = 375 } \\end{array} \\right.',
#    'stt': 268},
#   '_type': 'exam_bm25_01'},
#  {'_id': 269,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x = 2 + \\ldots', 'stt': 269},
#   '_type': 'exam_bm25_01'},
#  {'_id': 270,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'm x ^ { 2 } + n x + 1', 'stt': 270},
#   '_type': 'exam_bm25_01'},
#  {'_id': 271,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left\\{ \\begin{array} { l } { 2 x + y = 2 } \\\\ { x - y = 4 } \\end{array} \\right.',
#    'stt': 271},
#   '_type': 'exam_bm25_01'},
#  {'_id': 272,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left\\{ \\begin{array} { l } { 2 x + y = 2 } \\\\ { x - y = 4 } \\end{array} \\right.',
#    'stt': 272},
#   '_type': 'exam_bm25_01'},
#  {'_id': 273,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left\\{ \\begin{array} { l } { 3 x = 6 } \\\\ { x - y = 4 } \\end{array} \\right. \\Leftrightarrow \\left\\{ \\begin{array} { l } { x = 2 } \\\\ { y = - 2 } \\end{array} \\right.',
#    'stt': 273},
#   '_type': 'exam_bm25_01'},
#  {'_id': 274,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'S = x ^ { 2 }', 'stt': 274},
#   '_type': 'exam_bm25_01'},
#  {'_id': 275,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'S = x ^ { 2 }', 'stt': 275},
#   '_type': 'exam_bm25_01'},
#  {'_id': 276,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = \\frac { 1 } { 4 } x ^ { 2 }', 'stt': 276},
#   '_type': 'exam_bm25_01'},
#  {'_id': 277,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - \\frac { 1 } { 4 } x ^ { 2 }', 'stt': 277},
#   '_type': 'exam_bm25_01'},
#  {'_id': 278,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = \\frac { 1 } { 4 } x ^ { 2 }', 'stt': 278},
#   '_type': 'exam_bm25_01'},
#  {'_id': 279,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - \\frac { 1 } { 4 } x ^ { 2 }', 'stt': 279},
#   '_type': 'exam_bm25_01'},
#  {'_id': 280,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = x ^ { 2 }', 'stt': 280},
#   '_type': 'exam_bm25_01'},
#  {'_id': 281,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - x ^ { 2 }', 'stt': 281},
#   '_type': 'exam_bm25_01'},
#  {'_id': 282,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '- 2 , \\sqrt { 3 } , - \\sqrt { 3 }', 'stt': 282},
#   '_type': 'exam_bm25_01'},
#  {'_id': 283,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '- 3 , - 32', 'stt': 283},
#   '_type': 'exam_bm25_01'},
#  {'_id': 284,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = \\frac { x ^ { 2 } } { 2 }', 'stt': 284},
#   '_type': 'exam_bm25_01'},
#  {'_id': 285,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\Delta > 0', 'stt': 285},
#   '_type': 'exam_bm25_01'},
#  {'_id': 286,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x + \\frac { b } { 2 a } = \\pm \\ldots',
#    'stt': 286},
#   '_type': 'exam_bm25_01'},
#  {'_id': 287,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\Delta = 0', 'stt': 287},
#   '_type': 'exam_bm25_01'},
#  {'_id': 288,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\Delta < 0', 'stt': 288},
#   '_type': 'exam_bm25_01'},
#  {'_id': 289,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '235 x ^ { 2 } + 87 x - 197 = 0', 'stt': 289},
#   '_type': 'exam_bm25_01'},
#  {'_id': 290,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x ^ { 2 } - 2 x - 3 m ^ { 2 } - 1 = 0', 'stt': 290},
#   '_type': 'exam_bm25_01'},
#  {'_id': 291,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 x ^ { 2 } - 3 x - 5 = 0', 'stt': 291},
#   '_type': 'exam_bm25_01'},
#  {'_id': 292,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left. \\begin{array} { r } { b } \\\\ { - a } \\\\ { a } \\end{array} \\right.',
#    'stt': 292},
#   '_type': 'exam_bm25_01'},
#  {'_id': 293,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { c } { a }', 'stt': 293},
#   '_type': 'exam_bm25_01'},
#  {'_id': 294,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { x - 1 } { x + 1 } + \\frac { 1 } { x - 1 } = \\frac { 4 } { x ^ { 2 } - 1 }',
#    'stt': 294},
#   '_type': 'exam_bm25_01'},
#  {'_id': 295,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B D = 3,5 c m', 'stt': 295},
#   '_type': 'exam_bm25_01'},
#  {'_id': 296,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'M B ^ { 2 } + M C ^ { 2 }', 'stt': 296},
#   '_type': 'exam_bm25_01'},
#  {'_id': 297,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'm O n = x', 'stt': 297},
#   '_type': 'exam_bm25_01'},
#  {'_id': 298,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B C = x ; A C B = y', 'stt': 298},
#   '_type': 'exam_bm25_01'},
#  {'_id': 299,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 90 ^ { \\circ } - x', 'stt': 299},
#   '_type': 'exam_bm25_01'},
#  {'_id': 300,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { in } x = \\frac { 1 } { 2 }',
#    'stt': 300},
#   '_type': 'exam_bm25_01'},
#  {'_id': 301,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { sin } x = 0,174', 'stt': 301},
#   '_type': 'exam_bm25_01'},
#  {'_id': 302,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { sin } x = 0,519', 'stt': 302},
#   '_type': 'exam_bm25_01'},
#  {'_id': 303,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { cos } x = 0,342', 'stt': 303},
#   '_type': 'exam_bm25_01'},
#  {'_id': 304,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { tan } x = 1,254', 'stt': 304},
#   '_type': 'exam_bm25_01'},
#  {'_id': 305,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { cot } x = 0,856', 'stt': 305},
#   '_type': 'exam_bm25_01'},
#  {'_id': 306,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '60 ^ { \\circ }', 'stt': 306},
#   '_type': 'exam_bm25_01'},
#  {'_id': 307,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '40 ^ { \\circ } 12 ^ { \\prime }', 'stt': 307},
#   '_type': 'exam_bm25_01'},
#  {'_id': 308,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '52 ^ { \\circ } 54', 'stt': 308},
#   '_type': 'exam_bm25_01'},
#  {'_id': 309,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'o _ { 36 }', 'stt': 309},
#   '_type': 'exam_bm25_01'},
#  {'_id': 310,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '25 ^ { \\circ } 18 ^ { \\prime }', 'stt': 310},
#   '_type': 'exam_bm25_01'},
#  {'_id': 311,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 15 }', 'stt': 311},
#   '_type': 'exam_bm25_01'},
#  {'_id': 312,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 11 }', 'stt': 312},
#   '_type': 'exam_bm25_01'},
#  {'_id': 313,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { x } = 15', 'stt': 313},
#   '_type': 'exam_bm25_01'},
#  {'_id': 314,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 \\sqrt { x } = 14', 'stt': 314},
#   '_type': 'exam_bm25_01'},
#  {'_id': 315,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { x } < \\sqrt { 2 }', 'stt': 315},
#   '_type': 'exam_bm25_01'},
#  {'_id': 316,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 2 x } < 4', 'stt': 316},
#   '_type': 'exam_bm25_01'},
#  {'_id': 317,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 4 - 2 \\sqrt { 3 } } - \\sqrt { 3 } = - 1',
#    'stt': 317},
#   '_type': 'exam_bm25_01'},
#  {'_id': 318,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 16 } \\cdot \\sqrt { 25 } + \\sqrt { 196 } : \\sqrt { 49 }',
#    'stt': 318},
#   '_type': 'exam_bm25_01'},
#  {'_id': 319,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '36 : \\sqrt { 2.3 ^ { 2 } \\cdot 18 } - \\sqrt { 169 }',
#    'stt': 319},
#   '_type': 'exam_bm25_01'},
#  {'_id': 320,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { \\sqrt { 81 } }', 'stt': 320},
#   '_type': 'exam_bm25_01'},
#  {'_id': 321,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 3 ^ { 2 } + 4 ^ { 2 } }', 'stt': 321},
#   '_type': 'exam_bm25_01'},
#  {'_id': 322,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 \\sqrt { a ^ { 2 } } - 5 a', 'stt': 322},
#   '_type': 'exam_bm25_01'},
#  {'_id': 323,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'a < 0', 'stt': 323},
#   '_type': 'exam_bm25_01'},
#  {'_id': 324,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 25 a ^ { 2 } } + 3 a', 'stt': 324},
#   '_type': 'exam_bm25_01'},
#  {'_id': 325,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 9 a ^ { 4 } } + 3 a ^ { 2 }', 'stt': 325},
#   '_type': 'exam_bm25_01'},
#  {'_id': 326,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '5 \\sqrt { 4 a ^ { 6 } }', 'stt': 326},
#   '_type': 'exam_bm25_01'},
#  {'_id': 327,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '3 a ^ { 3 }', 'stt': 327},
#   '_type': 'exam_bm25_01'},
#  {'_id': 328,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'a < 0', 'stt': 328},
#   '_type': 'exam_bm25_01'},
#  {'_id': 329,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x ^ { 2 } - 3', 'stt': 329},
#   '_type': 'exam_bm25_01'},
#  {'_id': 330,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x ^ { 2 } - 6', 'stt': 330},
#   '_type': 'exam_bm25_01'},
#  {'_id': 331,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x ^ { 2 }', 'stt': 331},
#   '_type': 'exam_bm25_01'},
#  {'_id': 332,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 \\sqrt { 3 } x + 3', 'stt': 332},
#   '_type': 'exam_bm25_01'},
#  {'_id': 333,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x ^ { 2 }', 'stt': 333},
#   '_type': 'exam_bm25_01'},
#  {'_id': 334,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 \\sqrt { 5 } x + 5', 'stt': 334},
#   '_type': 'exam_bm25_01'},
#  {'_id': 335,
# ...
#   '_type': 'exam_bm25_01'},
#  {'_id': 895,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'p = \\frac { a + b + c } { 2 }', 'stt': 895},
#   '_type': 'exam_bm25_01'},
#  {'_id': 896,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B = a , A C = \\frac { a } { 2 } , B C = \\frac { a \\sqrt { 7 } } { 2 }',
#    'stt': 896},
#   '_type': 'exam_bm25_01'},
#  {'_id': 897,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt [ 3 ] { 216 }', 'stt': 897},
#   '_type': 'exam_bm25_01'},
#  {'_id': 898,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt [ 3 ] { - 512 }', 'stt': 898},
#   '_type': 'exam_bm25_01'},
#  {'_id': 899,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt [ 3 ] { 729 }', 'stt': 899},
#   '_type': 'exam_bm25_01'},
#  {'_id': 900,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt [ 3 ] { - 0,064 }', 'stt': 900},
#   '_type': 'exam_bm25_01'},
#  {'_id': 901,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt [ 3 ] { 0,027 }', 'stt': 901},
#   '_type': 'exam_bm25_01'},
#  {'_id': 902,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'M = \\frac { x } { 4 } + \\sqrt [ 3 ] { \\frac { x } { 3 } }',
#    'stt': 902},
#   '_type': 'exam_bm25_01'},
#  {'_id': 903,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x = 192', 'stt': 903},
#   '_type': 'exam_bm25_01'},
#  {'_id': 904,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'N = 2 y + \\sqrt [ 3 ] { - 45 y }', 'stt': 904},
#   '_type': 'exam_bm25_01'},
#  {'_id': 905,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 75', 'stt': 905},
#   '_type': 'exam_bm25_01'},
#  {'_id': 906,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt [ 3 ] { 64 } \\dots \\sqrt { 64 }',
#    'stt': 906},
#   '_type': 'exam_bm25_01'},
#  {'_id': 907,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt [ 3 ] { 0,001 \\dots } .0,01', 'stt': 907},
#   '_type': 'exam_bm25_01'},
#  {'_id': 908,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\frac { 1 } { - 4 } , \\sqrt [ 3 ] { \\frac { 8 } { - 125 } }',
#    'stt': 908},
#   '_type': 'exam_bm25_01'},
#  {'_id': 909,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 7 - 2 \\sqrt { 10 } } - \\sqrt { 6 - 2 \\sqrt { 5 } }',
#    'stt': 909},
#   '_type': 'exam_bm25_01'},
#  {'_id': 910,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 42 - 10 \\sqrt { 17 } } + \\sqrt { 33 - 8 \\sqrt { 17 } }',
#    'stt': 910},
#   '_type': 'exam_bm25_01'},
#  {'_id': 911,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 3 - \\sqrt { 5 } } - \\sqrt { 3 + \\sqrt { 5 } }',
#    'stt': 911},
#   '_type': 'exam_bm25_01'},
#  {'_id': 912,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 1', 'stt': 912},
#   '_type': 'exam_bm25_01'},
#  {'_id': 913,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 2 x + 1', 'stt': 913},
#   '_type': 'exam_bm25_01'},
#  {'_id': 914,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - 2 x + 2', 'stt': 914},
#   '_type': 'exam_bm25_01'},
#  {'_id': 915,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 2 x + b', 'stt': 915},
#   '_type': 'exam_bm25_01'},
#  {'_id': 916,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = a x + 1', 'stt': 916},
#   '_type': 'exam_bm25_01'},
#  {'_id': 917,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 2 m x + 1', 'stt': 917},
#   '_type': 'exam_bm25_01'},
#  {'_id': 918,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = x + 3', 'stt': 918},
#   '_type': 'exam_bm25_01'},
#  {'_id': 919,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = m x - 1', 'stt': 919},
#   '_type': 'exam_bm25_01'},
#  {'_id': 920,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = \\sqrt { 3 } x - 1', 'stt': 920},
#   '_type': 'exam_bm25_01'},
#  {'_id': 921,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '45 ^ { \\circ }', 'stt': 921},
#   '_type': 'exam_bm25_01'},
#  {'_id': 922,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '30 ^ { \\circ }', 'stt': 922},
#   '_type': 'exam_bm25_01'},
#  {'_id': 923,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = 3 x', 'stt': 923},
#   '_type': 'exam_bm25_01'},
#  {'_id': 924,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - 2 x + 105', 'stt': 924},
#   '_type': 'exam_bm25_01'},
#  {'_id': 925,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left\\{ \\begin{array} { l } { 3 x + y = 1 } \\\\ { 6 x + 2 y = 0 } \\end{array} \\right.',
#    'stt': 925},
#   '_type': 'exam_bm25_01'},
#  {'_id': 926,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left\\{ \\begin{array} { l } { x - y = 1 } \\\\ { 2 x - 2 y = 4 } \\end{array} \\right.',
#    'stt': 926},
#   '_type': 'exam_bm25_01'},
#  {'_id': 927,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left\\{ \\begin{array} { l } { x + y = 2 } \\\\ { x - y = 0 } \\end{array} \\right.',
#    'stt': 927},
#   '_type': 'exam_bm25_01'},
#  {'_id': 928,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left\\{ \\begin{array} { l } { x + 2 y = 3 } \\\\ { x + y = 2 } \\end{array} \\right.',
#    'stt': 928},
#   '_type': 'exam_bm25_01'},
#  {'_id': 929,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left\\{ \\begin{array} { l } { 2 x + y = 5 } \\\\ { 3 x + 2 y = 8 } \\end{array} \\right.',
#    'stt': 929},
#   '_type': 'exam_bm25_01'},
#  {'_id': 930,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left\\{ \\begin{array} { l } { 6 x - 3 y = 3 } \\\\ { - 6 x + 5 y = 3 } \\end{array} \\right.',
#    'stt': 930},
#   '_type': 'exam_bm25_01'},
#  {'_id': 931,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - x ^ { 2 }', 'stt': 931},
#   '_type': 'exam_bm25_01'},
#  {'_id': 932,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = x ^ { 2 }', 'stt': 932},
#   '_type': 'exam_bm25_01'},
#  {'_id': 933,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x \\neq 0', 'stt': 933},
#   '_type': 'exam_bm25_01'},
#  {'_id': 934,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x = 0', 'stt': 934},
#   '_type': 'exam_bm25_01'},
#  {'_id': 935,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = x ^ { 2 }', 'stt': 935},
#   '_type': 'exam_bm25_01'},
#  {'_id': 936,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - x ^ { 2 }', 'stt': 936},
#   '_type': 'exam_bm25_01'},
#  {'_id': 937,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - \\frac { 1 } { 2 } x ^ { 2 }', 'stt': 937},
#   '_type': 'exam_bm25_01'},
#  {'_id': 938,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - \\frac { 1 } { 2 } x ^ { 2 }', 'stt': 938},
#   '_type': 'exam_bm25_01'},
#  {'_id': 939,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = - \\frac { 1 } { 2 } x ^ { 2 }', 'stt': 939},
#   '_type': 'exam_bm25_01'},
#  {'_id': 940,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'K = \\frac { m v ^ { 2 } } { 2 }', 'stt': 940},
#   '_type': 'exam_bm25_01'},
#  {'_id': 941,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = a x ^ { 2 }', 'stt': 941},
#   '_type': 'exam_bm25_01'},
#  {'_id': 942,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = a x + b', 'stt': 942},
#   '_type': 'exam_bm25_01'},
#  {'_id': 943,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = \\frac { 1 } { 2 }', 'stt': 943},
#   '_type': 'exam_bm25_01'},
#  {'_id': 944,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'y = \\frac { 1 } { 4 } x ^ { 2 }', 'stt': 944},
#   '_type': 'exam_bm25_01'},
#  {'_id': 945,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\Leftrightarrow x ^ { 2 } + 2 x - 24 = 0',
#    'stt': 945},
#   '_type': 'exam_bm25_01'},
#  {'_id': 946,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 x ^ { 2 } + 3 x = 15 x', 'stt': 946},
#   '_type': 'exam_bm25_01'},
#  {'_id': 947,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2 x ^ { 2 } + 3 x = 15 x \\Leftrightarrow 2 x + 3 = 15',
#    'stt': 947},
#   '_type': 'exam_bm25_01'},
#  {'_id': 948,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\Leftrightarrow 2 x = 12 \\Leftrightarrow x = 6',
#    'stt': 948},
#   '_type': 'exam_bm25_01'},
#  {'_id': 949,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '{x^2} + 2x - 8 = 0', 'stt': 949},
#   '_type': 'exam_bm25_01'},
#  {'_id': 950,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '7 x ^ { 2 } - 3 x + 2 = 0', 'stt': 950},
#   '_type': 'exam_bm25_01'},
#  {'_id': 951,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '3 x ^ { 2 } - 2 \\sqrt { 3 } x + 1 = 0',
#    'stt': 951},
#   '_type': 'exam_bm25_01'},
#  {'_id': 952,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '- 2 x ^ { 2 } + 5 x + 2 = 0', 'stt': 952},
#   '_type': 'exam_bm25_01'},
#  {'_id': 953,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x ^ { 2 } - 250 x - m ^ { 2 } = 0', 'stt': 953},
#   '_type': 'exam_bm25_01'},
#  {'_id': 954,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '5 x ^ { 2 } - 2 x - 1 = 0', 'stt': 954},
#   '_type': 'exam_bm25_01'},
#  {'_id': 955,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '- x ^ { 2 } + 5 x + 2 = 0', 'stt': 955},
#   '_type': 'exam_bm25_01'},
#  {'_id': 956,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2016 x ^ { 2 } - 2017 x + 1 = 0', 'stt': 956},
#   '_type': 'exam_bm25_01'},
#  {'_id': 957,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '2016 x ^ { 2 } + 2017 + 1 = 0', 'stt': 957},
#   '_type': 'exam_bm25_01'},
#  {'_id': 958,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A . B = 0', 'stt': 958},
#   '_type': 'exam_bm25_01'},
#  {'_id': 959,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B = 0', 'stt': 959},
#   '_type': 'exam_bm25_01'},
#  {'_id': 960,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x ^ { 2 } + 2 x + m = 0', 'stt': 960},
#   '_type': 'exam_bm25_01'},
#  {'_id': 961,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x ^ { 2 } - 2 m x - 1 = 0', 'stt': 961},
#   '_type': 'exam_bm25_01'},
#  {'_id': 962,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x _ { 1 } ^ { 2 } + x _ { 2 } ^ { 2 } - x _ { 1 } x _ { 2 } = 15',
#    'stt': 962},
#   '_type': 'exam_bm25_01'},
#  {'_id': 963,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x _ { 1 } ^ { 2 } + x _ { 2 } ^ { 2 } - x _ { 1 } x _ { 2 } > 7',
#    'stt': 963},
#   '_type': 'exam_bm25_01'},
#  {'_id': 964,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x _ { 1 } ^ { 2 } + x _ { 2 } ^ { 2 } - x _ { 1 } x _ { 2 } - 20 \\leq 0',
#    'stt': 964},
#   '_type': 'exam_bm25_01'},
#  {'_id': 965,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'E = {x_1}^2 + {x_2}^2 - {x_1}{x_2} + 13',
#    'stt': 965},
#   '_type': 'exam_bm25_01'},
#  {'_id': 966,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\left. \\begin{array} { l } { \\wedge } \\\\ { C A B = x } \\end{array} \\right.',
#    'stt': 966},
#   '_type': 'exam_bm25_01'},
#  {'_id': 967,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '30 ^ { 0 }', 'stt': 967},
#   '_type': 'exam_bm25_01'},
#  {'_id': 968,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '60 ^ { \\circ }', 'stt': 968},
#   '_type': 'exam_bm25_01'},
#  {'_id': 969,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '45 ^ { \\circ }', 'stt': 969},
#   '_type': 'exam_bm25_01'},
#  {'_id': 970,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x = 40,542 ^ { \\circ }', 'stt': 970},
#   '_type': 'exam_bm25_01'},
#  {'_id': 971,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { sin } 76 ^ { \\circ } ; \\operatorname { cos } 31 ^ { \\circ } ; \\operatorname { tan } 83 ^ { \\circ } ; \\operatorname { cot } 88 ^ { \\circ }',
#    'stt': 971},
#   '_type': 'exam_bm25_01'},
#  {'_id': 972,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { cos } y = 0,79 ; \\operatorname { cot } y = 2,44',
#    'stt': 972},
#   '_type': 'exam_bm25_01'},
#  {'_id': 973,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B C = 5 c m ; A B = 3 c m', 'stt': 973},
#   '_type': 'exam_bm25_01'},
#  {'_id': 974,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'B C = 1 3 c m ; A C = 12 c m', 'stt': 974},
#   '_type': 'exam_bm25_01'},
#  {'_id': 975,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'BC = 5\\sqrt 2 cm;AB = 5cm', 'stt': 975},
#   '_type': 'exam_bm25_01'},
#  {'_id': 976,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'A B = a \\sqrt { 3 } ; A C = a', 'stt': 976},
#   '_type': 'exam_bm25_01'},
#  {'_id': 977,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'px = \\frac { 1 } { 3 }', 'stt': 977},
#   '_type': 'exam_bm25_01'},
#  {'_id': 978,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': ': \\operatorname { sin } 60 ^ { \\circ } , \\operatorname { cos } 75 ^ { \\circ } , \\operatorname { sin } 52 ^ { \\circ } 30 ^ { \\prime }',
#    'stt': 978},
#   '_type': 'exam_bm25_01'},
#  {'_id': 979,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { log } _ { x } = \\frac { 2 } { 3 }',
#    'stt': 979},
#   '_type': 'exam_bm25_01'},
#  {'_id': 980,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { cos } x = 0.6', 'stt': 980},
#   '_type': 'exam_bm25_01'},
#  {'_id': 981,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'c = \\frac { 3 } { 4 }', 'stt': 981},
#   '_type': 'exam_bm25_01'},
#  {'_id': 982,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 'x = \\frac { 3 } { 2 }', 'stt': 982},
#   '_type': 'exam_bm25_01'},
#  {'_id': 983,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { sin } x = 0,2368', 'stt': 983},
#   '_type': 'exam_bm25_01'},
#  {'_id': 984,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { cos } x = 0,6224', 'stt': 984},
#   '_type': 'exam_bm25_01'},
#  {'_id': 985,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { tan } x = 2,154', 'stt': 985},
#   '_type': 'exam_bm25_01'},
#  {'_id': 986,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { cot } x = 3,251', 'stt': 986},
#   '_type': 'exam_bm25_01'},
#  {'_id': 987,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { in } = 00', 'stt': 987},
#   '_type': 'exam_bm25_01'},
#  {'_id': 988,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { cos } 22 ^ { \\circ }',
#    'stt': 988},
#   '_type': 'exam_bm25_01'},
#  {'_id': 989,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '78 ^ { \\circ }', 'stt': 989},
#   '_type': 'exam_bm25_01'},
#  {'_id': 990,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { tan } 52 ^ { \\circ }',
#    'stt': 990},
#   '_type': 'exam_bm25_01'},
#  {'_id': 991,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': 't 14 ^ { o }', 'stt': 991},
#   '_type': 'exam_bm25_01'},
#  {'_id': 992,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '32 ^ { \\circ }', 'stt': 992},
#   '_type': 'exam_bm25_01'},
#  {'_id': 993,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '32 ^ { \\circ }', 'stt': 993},
#   '_type': 'exam_bm25_01'},
#  {'_id': 994,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { tan } 25 ^ { \\circ }',
#    'stt': 994},
#   '_type': 'exam_bm25_01'},
#  {'_id': 995,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { sin } 25 ^ { \\circ }',
#    'stt': 995},
#   '_type': 'exam_bm25_01'},
#  {'_id': 996,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\operatorname { tan } 45 ^ { \\circ }',
#    'stt': 996},
#   '_type': 'exam_bm25_01'},
#  {'_id': 997,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '45 ^ { \\circ }', 'stt': 997},
#   '_type': 'exam_bm25_01'},
#  {'_id': 998,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '+ 32 ^ { \\circ }', 'stt': 998},
#   '_type': 'exam_bm25_01'},
#  {'_id': 999,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '32 ^ { \\circ }', 'stt': 999},
#   '_type': 'exam_bm25_01'},
#  {'_id': 1000,
#   '_index': 'idx_formular_00',
#   '_source': {'formular': '\\sqrt { 3 }', 'stt': 1000},
#   '_type': 'exam_bm25_01'},
#  ...]

# %%
# insert data
helpers.bulk(es, bulk_data)
# Out:
# (1674, [])

# %%
es.indices.refresh(index = "idx_formular_00")
# Out:
# {'_shards': {'failed': 0, 'successful': 5, 'total': 10}}

# %%
a = es.search(index = "idx_formular_00", body = {
    "query": {
        "match": {
            "formular": "\\frac { 3 } { 2 + a }"
        }
    }
})

# %%
for i in a['hits']['hits']:
    print("score : {} and formular : {}".format(i['_score'], i['_source']['formular']))
    print(" ")
# Out:
# score : 6.0467944 and formular : \sqrt { \frac { 2 a } { 3 } }
#
# score : 5.9997387 and formular : \sqrt { \frac { 3 } { 2 a ^ { 2 } } }
#
# score : 5.8697634 and formular : \frac { 2 a } { \sqrt { 3 } }
#
# score : 5.7890425 and formular : \sqrt { \frac { 2 a } { 3 } }
#
# score : 5.7078996 and formular : \frac { a } { 3 }
#
# score : 5.664493 and formular : - \frac { a } { 3 }
#
# score : 5.6155534 and formular : A B = \frac { 2 } { 3 } A C
#
# score : 5.1236954 and formular : \frac { 1 } { 2 \sqrt { 3 } + 3 } - \frac { 1 } { 2 \sqrt { 3 } - 3 }
#
# score : 5.1206703 and formular : y = \frac { 3 } { 2 } x ^ { 2 } , y = - \frac { 3 } { 2 } x ^ { 2 }
#
# score : 5.1124716 and formular : \frac { \sqrt { 3 } } { 2 }

# %%
# delete index
es.indices.delete(index = "idx_formular_00")
# Out:
# {'acknowledged': True}
